# %% [markdown]
# ## Running OWL2Vec*

# %%
#!pip install jupyter==1.0.0
#!pip install rdflib==7.0.0
#!pip install pyparsing==2.4.7
#!pip install scipy==1.12.0
#!pip install numpy==1.26.4 
#!pip install gensim==4.3.1
#!pip install scikit-learn==1.4.0
#!pip install nltk==3.8.1
#!pip install OWLready2==0.45
#!pip install setuptools==69.2.0 
#!pip install pandas==2.2.2

# %% [markdown]
# ### from the lab

# %%
from owl2vec_star import owl2vec_star


#Parameters:
# ontology_file
# config_file
# uri_doc
# lit_doc
# mix_doc
gensim_model = owl2vec_star.extract_owl2vec_model("./case_studies/pizza/pizza.owl", "./default.cfg", True, True, True)

output_folder="./cache/output/"

#Gensim format
gensim_model.save(output_folder+"ontology.embeddings")
    #Txt format
gensim_model.wv.save_word2vec_format(output_folder+"ontology.embeddings.txt", binary=False)
# Out:
# * Owlready2 * Warning: optimized Cython parser module 'owlready2_optimized' is not available, defaulting to slower Python implementation
# [nltk_data] Downloading package punkt to C:\Users\Fasih
# [nltk_data]     Munir\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# INFO: Access the ontology ...
# INFO: There are 1945 triples in the ontology
# INFO: Calculate the ontology projection ...
# INFO: Creating ontology graph projection...
# INFO: 	Extracting subsumption triples
# INFO: 		Time extracting subsumption: 0.8154659271240234 seconds
# INFO: 	Extracting equivalence triples
# INFO: 		Time extracting equivalences: 0.023654460906982422 seconds
# INFO: 	Extracting class membership triples.
# INFO: 		Time extracting class membership: 0.1835026741027832 seconds
# INFO: 	Extracting sameAs triples
# INFO: 		Time extracting sameAs: 0.007008552551269531 seconds
# INFO: 	Extracting triples associated to hasBase
# INFO: 		Time extracting triples for property: 0.14656686782836914 seconds
# INFO: 	Extracting triples associated to hasIngredient
# INFO: 		Time extracting triples for property: 0.09192728996276855 seconds
# INFO: 	Extracting triples associated to isBaseOf
# INFO: 		Time extracting triples for property: 0.08851957321166992 seconds
# INFO: 	Extracting triples associated to hasCountryOfOrigin
# INFO: 		Time extracting triples for property: 0.09744739532470703 seconds
# INFO: 	Extracting triples associated to isIngredientOf
# INFO: 		Time extracting triples for property: 0.08875656127929688 seconds
# INFO: 	Extracting triples associated to hasSpiciness
# INFO: 		Time extracting triples for property: 0.10090923309326172 seconds
# INFO: 	Extracting triples associated to hasTopping
# INFO: 		Time extracting triples for property: 0.1252727508544922 seconds
# INFO: 	Extracting triples associated to isToppingOf
# INFO: 		Time extracting triples for property: 0.09152841567993164 seconds
# INFO: 	Extracting data property assertions
# INFO: 		Time extracting data property assertions: 0.0010082721710205078 seconds
# INFO: 	Extracting complex equivalence axioms
# INFO: 		Time extracting complex equivalence axioms: 3.171344041824341 seconds
# INFO: 	Extracting annotations.
# INFO: 		Time extracting annotations: 0.3490293025970459 seconds
# INFO: Projection created into a Graph object (RDFlib library)
# INFO: Projection saved into turtle file: ./cache/projection.ttl
# INFO: Extract classes and individuals ...
# INFO: Extract axioms ...
# INFO: Extract annotations ...
# INFO: Generate URI document ...
# INFO: Extracted 3350 walks for 104 seed entities
# INFO: Extracted 279 axiom sentences
# INFO: Generate literal document ...
# INFO: Extracted 34 annotation sentences
# INFO: Generate mixture document ...
# INFO: URI_Doc: 3629, Lit_Doc: 12069, Mix_Doc: 3629
# INFO: Time for document construction: 6.579423427581787 seconds
# INFO: Train the language model ...
# INFO: collecting all words and their counts
# INFO: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO: PROGRESS: at sentence #10000, processed 58705 words, keeping 640 word types
# INFO: collected 784 word types from a corpus of 113124 raw words and 19327 sentences
# INFO: Creating a fresh vocabulary
# INFO: Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 784 unique words (100.00% of original 784, drops 0)', 'datetime': '2024-05-12T10:29:26.406813', 'gensim': '4.3.1', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'prepare_vocab'}
# INFO: Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 113124 word corpus (100.00% of original 113124, drops 0)', 'datetime': '2024-05-12T10:29:26.407806', 'gensim': '4.3.1', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'prepare_vocab'}
# INFO: deleting the raw counts dictionary of 784 items
# INFO: sample=0.001 downsamples 61 most-common words
# INFO: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 53204.81650085624 word corpus (47.0%% of prior 113124)', 'datetime': '2024-05-12T10:29:26.411815', 'gensim': '4.3.1', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'prepare_vocab'}
# INFO: estimated required memory for 784 words and 100 dimensions: 1019200 bytes
# INFO: resetting layer weights
# INFO: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2024-05-12T10:29:26.419461', 'gensim': '4.3.1', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'build_vocab'}
# INFO: Word2Vec lifecycle event {'msg': 'training model with 16 workers on 784 vocabulary and 100 features, using sg=1 hs=0 sample=0.001 negative=25 window=5 shrink_windows=True', 'datetime': '2024-05-12T10:29:26.420463', 'gensim': '4.3.1', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'train'}
# INFO: EPOCH 0: training on 113124 raw words (53254 effective words) took 0.1s, 873427 effective words/s
# INFO: EPOCH 1: training on 113124 raw words (53217 effective words) took 0.1s, 979868 effective words/s
# INFO: EPOCH 2: training on 113124 raw words (53277 effective words) took 0.1s, 937918 effective words/s
# INFO: EPOCH 3: training on 113124 raw words (53273 effective words) took 0.1s, 935185 effective words/s
# INFO: EPOCH 4: training on 113124 raw words (53185 effective words) took 0.1s, 951436 effective words/s
# INFO: EPOCH 5: training on 113124 raw words (53163 effective words) took 0.1s, 945838 effective words/s
# INFO: EPOCH 6: training on 113124 raw words (53182 effective words) took 0.1s, 882703 effective words/s
# INFO: EPOCH 7: training on 113124 raw words (53215 effective words) took 0.1s, 998016 effective words/s
# INFO: EPOCH 8: training on 113124 raw words (53190 effective words) took 0.1s, 882040 effective words/s
# INFO: EPOCH 9: training on 113124 raw words (53190 effective words) took 0.1s, 885976 effective words/s
# INFO: Word2Vec lifecycle event {'msg': 'training on 1131240 raw words (532146 effective words) took 0.7s, 717426 effective words/s', 'datetime': '2024-05-12T10:29:27.161879', 'gensim': '4.3.1', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'train'}
# INFO: Word2Vec lifecycle event {'params': 'Word2Vec<vocab=784, vector_size=100, alpha=0.025>', 'datetime': '2024-05-12T10:29:27.162883', 'gensim': '4.3.1', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'created'}
# INFO: Time for learning the language model: 0.7832002639770508 seconds
# INFO: Word2Vec lifecycle event {'fname_or_handle': './cache/output/ontology.embeddings', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2024-05-12T10:29:27.168883', 'gensim': '4.3.1', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'saving'}
# INFO: not storing attribute cum_table
# INFO: saved ./cache/output/ontology.embeddings
# INFO: storing 784x100 projection weights into ./cache/output/ontology.embeddings.txt

# %% [markdown]
# #### Loading embeddings and getting similarities

# %%
from gensim.models import KeyedVectors

#Embedding vectors generated above
model = KeyedVectors.load("./cache/output/ontology.embeddings", mmap='r')
wv = model.wv

vector = wv['pizza']  # Get numpy vector of a word
print("Vector for 'pizza'")
print(vector)

#cosine similarity
similarity = wv.similarity('pizza', 'http://www.co-ode.org/ontologies/pizza/pizza.owl#Pizza')
print(similarity)

similarity = wv.similarity('http://www.co-ode.org/ontologies/pizza/pizza.owl#Margherita', 'margherita')
print(similarity)


#Most similar cosine similarity
result = wv.most_similar(positive=['margherita', 'pizza'])
print(result)

#Most similar entities: cosmul
result = wv.most_similar_cosmul(positive=['margherita'])
print(result)
# Out:
# INFO: loading KeyedVectors object from ./cache/output/ontology.embeddings
# INFO: loading wv recursively from ./cache/output/ontology.embeddings.wv.* with mmap=r
# INFO: setting ignored attribute cum_table to None
# INFO: Word2Vec lifecycle event {'fname': './cache/output/ontology.embeddings', 'datetime': '2024-05-12T10:29:27.230990', 'gensim': '4.3.1', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'loaded'}
# Vector for 'pizza'
# [-0.35208783  0.4368985   0.20925592  0.6697823   0.06111518  0.30470192
#  -0.3959306  -0.21964304 -0.4625729  -0.07736258 -0.0737689   0.36331636
#   0.49076882 -0.22288145 -0.0102441   0.07475019  0.54505837 -0.95993793
#   0.33339405  0.02049149  0.05990061  0.18572415  0.149573    0.58744216
#   0.19489491 -0.20691772  0.39691544 -0.01546526 -0.18707787  0.29640996
#  -0.517227   -0.44690946 -0.20935677 -0.45724204  0.19369175 -0.29058358
#   0.3926295   0.32093066 -0.43909982 -0.11507002  0.19123915  0.07252536
#  -0.43595603 -0.15474185 -0.06024755 -0.05622103 -0.01502387  0.1620362
#   0.2283897   0.02902427  0.18861908  0.30497012 -0.25410876 -0.42386362
#   0.11755227 -0.13312133  0.26299927 -0.30372876  0.2750289   0.00300724
#   0.32037932 -0.02150279 -0.16717035 -0.09260186  0.09661588  0.27102265
#   0.04700339  0.12033629 -0.30562702 -0.32709816  0.55238837 -0.7406147
#  -0.30856127 -0.414008   -0.32200167  0.1304826   0.19954146 -0.316769
#  -0.08567644 -0.49095532  0.01389351  0.2969851  -0.34030554  0.18234971
#  -0.19755052 -0.11774158 -0.6460657  -0.01581393  0.21510196  0.5296229
#   0.5372622   0.6805434   0.5036367   0.51462805  0.09646967 -0.04377915
#   0.09078065 -0.2754117   0.45644453 -0.07761278]
# 0.47371885
# 0.7523553
# [('unclosedpizza', 0.8066076040267944), ('margherita pizza', 0.7976540327072144), ('rosa pizza', 0.7936446070671082), ('caprina pizza', 0.7902492880821228), ('parmese pizza', 0.7900791764259338), ('sloppy giuseppe pizza', 0.7639515995979309), ('prince carlo pizza', 0.7607588768005371), ('mushroom pizza', 0.7586240768432617), ('fiorentina pizza', 0.756901741027832), ('giardiniera pizza', 0.7440800666809082)]
# [('unclosed', 0.9153203964233398), ('unclosedpizza', 0.9121875166893005), ('rosa pizza', 0.8856943845748901), ('parmese pizza', 0.8855560421943665), ('margherita pizza', 0.8835861682891846), ('http://www.co-ode.org/ontologies/pizza/pizza.owl#Margherita', 0.8761768341064453), ('caprina pizza', 0.8753329515457153), ('http://www.co-ode.org/ontologies/pizza/pizza.owl#Rosa', 0.8667021989822388), ('Margherita Pizza', 0.8647910952568054), ('Mushroom Pizza', 0.8646759986877441)]

# %% [markdown]
# ### 2.5 Ontology Embeddings (Task Vector)
#
# original similarity scores are in the report. running this code recalculates the scores but they do dont differ much. scores are all within the same range maybe differences of approximataley 0.05 give or take.

# %% [markdown]
# Quick notes about parameters:
#
# 1. Walker Type - wl or random. captures node structurewl can get complex information vs random walks. wl more intensive than simple random
# 3. Walk Depth - how deep to walk or go down in the structure. going deeper brings more context and wider relations. going deeper increases computation and may get too deep connecting too different concepts
# 8. Embedding Size - size of vectors. larger vectors store more compex information require more compute
# 9. Iteration - how many times the data is passed through. more is good but too much more can over fit ie learn too much
# 10. Window Size - distance between current word and predicted word in a sentence. small window only looks at immidiate context (like uni or bi gram). small window can miss out on wide context
# 11. Minimum Count - count of times a word should be included - count of 1 means every word is included but if they actually have a count of 1 then they are rare and can introduce noise
# 12. Negative Sampling - amount of noise. used to distinguish words

# %% [markdown]
# #### Subtask Vector.1

# %% [markdown]
# ##### Configuration 1
#
# taken the code from lab 9, following the instructions and just updating the respective files

# %%
#loading the ontologies and saving in a single graph to pass to word2vec

from rdflib import Graph
from rdflib import URIRef, BNode, Literal
from rdflib import Namespace
from rdflib.namespace import OWL, RDF, RDFS, FOAF, XSD
from rdflib.util import guess_format

g = Graph()
g.parse('generated_rdf.ttl', format = 'ttl')
g.parse('pizza-restaurants-ontology.ttl', format = 'ttl')

g.serialize('ontology_for_embeddings.ttl', format = 'ttl')

turtle_path = 'ontology_for_embeddings.ttl'
g.parse(turtle_path, format='turtle')
output_owl = 'ontology_for_embeddings.owl'
g.serialize(output_owl, format='xml')
# Out:
# <Graph identifier=N9e26f1af33864f4cb90778f0fd79ab01 (<class 'rdflib.graph.Graph'>)>

# %%
#Parameters:
# ontology_file
# config_file
# uri_doc
# lit_doc
# mix_doc

#Config 1:
#walker = wl
#walk_depth = 5
#URI_Doc = yes
#Lit_Doc = yes
#Mix_Doc = no
#Mix_Type = random
#embed_size = 100
#iteration = 10
#window = 2
#min_count = 1
#negative = 30
#seed = 42
#epoch = 100

gensim_model1 = owl2vec_star.extract_owl2vec_model(
    r"C:\Users\Fasih Munir\Desktop\Knowledge Graphs Final Coursework\OWL2Vec-Star-IN3067-INM713\OWL2Vec-Star-master\ontology_for_embeddings.owl",
    "default_updated_config_1.cfg", True, True, True)

output_folder="./cache/output/"

#one binary and one non binary file
gensim_model1.wv.save_word2vec_format(output_folder+"ontology.embeddings.config1.txt", binary=False)
gensim_model1.save(output_folder+"ontology.embeddings.config1")
# Out:
# INFO: Access the ontology ...
# * Owlready2 * Creating new ontology C:\Users\Fasih Munir\Desktop\Knowledge Graphs Final Coursework\OWL2Vec-Star-IN3067-INM713\OWL2Vec-Star-master\ontology_for_embeddings <C:\Users\Fasih Munir\Desktop\Knowledge Graphs Final Coursework\OWL2Vec-Star-IN3067-INM713\OWL2Vec-Star-master\ontology_for_embeddings.owl#>.
# * Owlready2 * ADD TRIPLE C:\Users\Fasih Munir\Desktop\Knowledge Graphs Final Coursework\OWL2Vec-Star-IN3067-INM713\OWL2Vec-Star-master\ontology_for_embeddings.owl http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#Ontology
# WARNING: C:\Users\Fasih Munir\Desktop\Knowledge Graphs Final Coursework\OWL2Vec-Star-IN3067-INM713\OWL2Vec-Star-master\ontology_for_embeddings.owl# does not look like a valid URI, trying to serialize this will break.
# * Owlready2 *     ...loading ontology C:\Users\Fasih Munir\Desktop\Knowledge Graphs Final Coursework\OWL2Vec-Star-IN3067-INM713\OWL2Vec-Star-master\ontology_for_embeddings from C:\Users\Fasih Munir\Desktop\Knowledge Graphs Final Coursework\OWL2Vec-Star-IN3067-INM713\OWL2Vec-Star-master\ontology_for_embeddings.owl...
# * Owlready2 *     ...25 properties found: locatedInCity, locatedInAddress, serves, hasIngredient, locatedInState, amountCurrency, locatedIn, isIngredientOf, servesMenuItem, locatedInCountry, containsLocation, hasValue, containsCity, servedIn, servedInRestaurant, containsAdress, containsState, amount, itemName, postCode, firstLineAddress, restaurantName, name, altLabel, creator
# INFO: There are 6336 triples in the ontology
# INFO: Calculate the ontology projection ...
# INFO: Creating ontology graph projection...
# INFO: 	Extracting subsumption triples
# INFO: 		Time extracting subsumption: 0.10352063179016113 seconds
# INFO: 	Extracting equivalence triples
# INFO: 		Time extracting equivalences: 0.030910730361938477 seconds
# INFO: 	Extracting class membership triples.
# * Owlready2 * Reseting property core.altLabel: new triples are now available.
# INFO: 		Time extracting class membership: 0.7552568912506104 seconds
# INFO: 	Extracting sameAs triples
# INFO: 		Time extracting sameAs: 0.007184505462646484 seconds
# INFO: 	Extracting triples associated to locatedInCity
# INFO: 		Time extracting triples for property: 0.11867904663085938 seconds
# INFO: 	Extracting triples associated to locatedInAddress
# INFO: 		Time extracting triples for property: 0.10186934471130371 seconds
# INFO: 	Extracting triples associated to serves
# INFO: 		Time extracting triples for property: 0.1018974781036377 seconds
# INFO: 	Extracting triples associated to hasIngredient
# INFO: 		Time extracting triples for property: 0.141737699508667 seconds
# INFO: 	Extracting triples associated to locatedInState
# INFO: 		Time extracting triples for property: 0.10561513900756836 seconds
# INFO: 	Extracting triples associated to amountCurrency
# INFO: 		Time extracting triples for property: 0.10904431343078613 seconds
# INFO: 	Extracting triples associated to locatedIn
# INFO: 		Time extracting triples for property: 0.11778140068054199 seconds
# INFO: 	Extracting triples associated to isIngredientOf
# INFO: 		Time extracting triples for property: 0.10894250869750977 seconds
# INFO: 	Extracting triples associated to servesMenuItem
# INFO: 		Time extracting triples for property: 0.09197187423706055 seconds
# INFO: 	Extracting triples associated to locatedInCountry
# INFO: 		Time extracting triples for property: 0.10008573532104492 seconds
# INFO: 	Extracting triples associated to containsLocation
# INFO: 		Time extracting triples for property: 0.09023356437683105 seconds
# INFO: 	Extracting triples associated to hasValue
# INFO: 		Time extracting triples for property: 0.09736299514770508 seconds
# INFO: 	Extracting triples associated to containsCity
# INFO: 		Time extracting triples for property: 0.08899903297424316 seconds
# INFO: 	Extracting triples associated to servedIn
# INFO: 		Time extracting triples for property: 0.18146610260009766 seconds
# INFO: 	Extracting triples associated to servedInRestaurant
# INFO: 		Time extracting triples for property: 0.09099340438842773 seconds
# INFO: 	Extracting triples associated to containsAdress
# INFO: 		Time extracting triples for property: 0.08800292015075684 seconds
# INFO: 	Extracting triples associated to containsState
# INFO: 		Time extracting triples for property: 0.09407806396484375 seconds
# INFO: 	Extracting data property assertions
# INFO: 		Time extracting data property assertions: 0.14486980438232422 seconds
# INFO: 	Extracting complex equivalence axioms
# INFO: 		Time extracting complex equivalence axioms: 0.5732262134552002 seconds
# INFO: 	Extracting annotations.
# INFO: 		Time extracting annotations: 0.5098984241485596 seconds
# INFO: Projection created into a Graph object (RDFlib library)
# INFO: Projection saved into turtle file: ./cache/projection.ttl
# INFO: Extract classes and individuals ...
# INFO: Extract axioms ...
# INFO: Extract annotations ...
# INFO: Generate URI document ...
# INFO: Extracted 170535 walks for 151 seed entities
# INFO: Extracted 2519 axiom sentences
# INFO: Generate literal document ...
# INFO: Extracted 17 annotation sentences
# INFO: Generate mixture document ...
# INFO: URI_Doc: 173054, Lit_Doc: 178873, Mix_Doc: 173054
# INFO: Time for document construction: 14.505221366882324 seconds
# INFO: Train the language model ...
# INFO: collecting all words and their counts
# INFO: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO: PROGRESS: at sentence #10000, processed 81202 words, keeping 4839 word types
# INFO: PROGRESS: at sentence #20000, processed 162642 words, keeping 6536 word types
# INFO: PROGRESS: at sentence #30000, processed 244024 words, keeping 7570 word types
# INFO: PROGRESS: at sentence #40000, processed 325189 words, keeping 8294 word types
# INFO: PROGRESS: at sentence #50000, processed 406822 words, keeping 8783 word types
# INFO: PROGRESS: at sentence #60000, processed 488174 words, keeping 9151 word types
# INFO: PROGRESS: at sentence #70000, processed 569639 words, keeping 9489 word types
# INFO: PROGRESS: at sentence #80000, processed 650934 words, keeping 9757 word types
# INFO: PROGRESS: at sentence #90000, processed 732309 words, keeping 9952 word types
# INFO: PROGRESS: at sentence #100000, processed 813676 words, keeping 10134 word types
# INFO: PROGRESS: at sentence #110000, processed 895138 words, keeping 10299 word types
# INFO: PROGRESS: at sentence #120000, processed 976286 words, keeping 10446 word types
# INFO: PROGRESS: at sentence #130000, processed 1057722 words, keeping 10571 word types
# INFO: PROGRESS: at sentence #140000, processed 1138800 words, keeping 10681 word types
# INFO: PROGRESS: at sentence #150000, processed 1219790 words, keeping 10780 word types
# INFO: PROGRESS: at sentence #160000, processed 1300836 words, keeping 10880 word types
# INFO: PROGRESS: at sentence #170000, processed 1381614 words, keeping 10993 word types
# INFO: PROGRESS: at sentence #180000, processed 1462939 words, keeping 11063 word types
# INFO: PROGRESS: at sentence #190000, processed 1544295 words, keeping 11144 word types
# INFO: PROGRESS: at sentence #200000, processed 1625518 words, keeping 11219 word types
# INFO: PROGRESS: at sentence #210000, processed 1706690 words, keeping 11290 word types
# INFO: PROGRESS: at sentence #220000, processed 1787916 words, keeping 11347 word types
# INFO: PROGRESS: at sentence #230000, processed 1868996 words, keeping 11414 word types
# INFO: PROGRESS: at sentence #240000, processed 1950570 words, keeping 11472 word types
# INFO: PROGRESS: at sentence #250000, processed 2032011 words, keeping 11532 word types
# INFO: PROGRESS: at sentence #260000, processed 2113319 words, keeping 11584 word types
# INFO: PROGRESS: at sentence #270000, processed 2194170 words, keeping 11631 word types
# INFO: PROGRESS: at sentence #280000, processed 2275514 words, keeping 11682 word types
# INFO: PROGRESS: at sentence #290000, processed 2356909 words, keeping 11736 word types
# INFO: PROGRESS: at sentence #300000, processed 2438469 words, keeping 11786 word types
# INFO: PROGRESS: at sentence #310000, processed 2519632 words, keeping 11816 word types
# INFO: PROGRESS: at sentence #320000, processed 2600335 words, keeping 11860 word types
# INFO: PROGRESS: at sentence #330000, processed 2681578 words, keeping 11893 word types
# INFO: PROGRESS: at sentence #340000, processed 2762814 words, keeping 11934 word types
# INFO: PROGRESS: at sentence #350000, processed 2843686 words, keeping 11969 word types
# INFO: PROGRESS: at sentence #360000, processed 2925089 words, keeping 12008 word types
# INFO: PROGRESS: at sentence #370000, processed 3006470 words, keeping 12055 word types
# INFO: PROGRESS: at sentence #380000, processed 3087963 words, keeping 12089 word types
# INFO: PROGRESS: at sentence #390000, processed 3168878 words, keeping 12127 word types
# INFO: PROGRESS: at sentence #400000, processed 3250220 words, keeping 12172 word types
# INFO: PROGRESS: at sentence #410000, processed 3331611 words, keeping 12206 word types
# INFO: PROGRESS: at sentence #420000, processed 3412745 words, keeping 12243 word types
# INFO: PROGRESS: at sentence #430000, processed 3493929 words, keeping 12286 word types
# INFO: PROGRESS: at sentence #440000, processed 3575112 words, keeping 12321 word types
# INFO: PROGRESS: at sentence #450000, processed 3655931 words, keeping 12352 word types
# INFO: PROGRESS: at sentence #460000, processed 3737015 words, keeping 12376 word types
# INFO: PROGRESS: at sentence #470000, processed 3818448 words, keeping 12418 word types
# INFO: PROGRESS: at sentence #480000, processed 3899128 words, keeping 12445 word types
# INFO: PROGRESS: at sentence #490000, processed 3980096 words, keeping 12467 word types
# INFO: PROGRESS: at sentence #500000, processed 4061198 words, keeping 12501 word types
# INFO: PROGRESS: at sentence #510000, processed 4142289 words, keeping 12522 word types
# INFO: PROGRESS: at sentence #520000, processed 4223499 words, keeping 12550 word types
# INFO: collected 12564 word types from a corpus of 4264099 raw words and 524981 sentences
# INFO: Creating a fresh vocabulary
# INFO: Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 12564 unique words (100.00% of original 12564, drops 0)', 'datetime': '2024-05-12T10:29:46.214230', 'gensim': '4.3.1', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'prepare_vocab'}
# INFO: Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 4264099 word corpus (100.00% of original 4264099, drops 0)', 'datetime': '2024-05-12T10:29:46.214230', 'gensim': '4.3.1', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'prepare_vocab'}
# INFO: deleting the raw counts dictionary of 12564 items
# INFO: sample=0.001 downsamples 44 most-common words
# INFO: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 2268078.8426299747 word corpus (53.2%% of prior 4264099)', 'datetime': '2024-05-12T10:29:46.261238', 'gensim': '4.3.1', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'prepare_vocab'}
# INFO: estimated required memory for 12564 words and 100 dimensions: 16333200 bytes
# INFO: resetting layer weights
# INFO: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2024-05-12T10:29:46.333758', 'gensim': '4.3.1', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'build_vocab'}
# INFO: Word2Vec lifecycle event {'msg': 'training model with 16 workers on 12564 vocabulary and 100 features, using sg=1 hs=0 sample=0.001 negative=30 window=2 shrink_windows=True', 'datetime': '2024-05-12T10:29:46.334760', 'gensim': '4.3.1', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'train'}
# INFO: EPOCH 0 - PROGRESS: at 43.35% examples, 982066 words/s, in_qsize 30, out_qsize 1
# INFO: EPOCH 0 - PROGRESS: at 90.95% examples, 1029109 words/s, in_qsize 31, out_qsize 0
# INFO: EPOCH 0: training on 4264099 raw words (2267862 effective words) took 2.2s, 1052553 effective words/s
# INFO: EPOCH 1 - PROGRESS: at 44.28% examples, 986512 words/s, in_qsize 31, out_qsize 0
# INFO: EPOCH 1 - PROGRESS: at 91.42% examples, 1023484 words/s, in_qsize 25, out_qsize 6
# INFO: EPOCH 1: training on 4264099 raw words (2268088 effective words) took 2.2s, 1051569 effective words/s
# INFO: EPOCH 2 - PROGRESS: at 41.46% examples, 916288 words/s, in_qsize 31, out_qsize 0
# INFO: EPOCH 2 - PROGRESS: at 91.42% examples, 1016222 words/s, in_qsize 30, out_qsize 1
# INFO: EPOCH 2: training on 4264099 raw words (2267613 effective words) took 2.2s, 1042405 effective words/s
# INFO: EPOCH 3 - PROGRESS: at 44.05% examples, 979166 words/s, in_qsize 31, out_qsize 0
# INFO: EPOCH 3 - PROGRESS: at 92.83% examples, 1040443 words/s, in_qsize 30, out_qsize 1
# INFO: EPOCH 3: training on 4264099 raw words (2267161 effective words) took 2.1s, 1067462 effective words/s
# INFO: EPOCH 4 - PROGRESS: at 45.22% examples, 1011292 words/s, in_qsize 31, out_qsize 0
# INFO: EPOCH 4 - PROGRESS: at 92.12% examples, 1034151 words/s, in_qsize 28, out_qsize 3
# INFO: EPOCH 4: training on 4264099 raw words (2267186 effective words) took 2.1s, 1059786 effective words/s
# INFO: EPOCH 5 - PROGRESS: at 40.53% examples, 907410 words/s, in_qsize 31, out_qsize 0
# INFO: EPOCH 5 - PROGRESS: at 88.12% examples, 973599 words/s, in_qsize 25, out_qsize 9
# INFO: EPOCH 5: training on 4264099 raw words (2269058 effective words) took 2.2s, 1025416 effective words/s
# INFO: EPOCH 6 - PROGRESS: at 42.17% examples, 955365 words/s, in_qsize 32, out_qsize 3
# INFO: EPOCH 6 - PROGRESS: at 93.30% examples, 1057335 words/s, in_qsize 29, out_qsize 0
# INFO: EPOCH 6: training on 4264099 raw words (2268075 effective words) took 2.1s, 1078942 effective words/s
# INFO: EPOCH 7 - PROGRESS: at 45.45% examples, 1015180 words/s, in_qsize 27, out_qsize 4
# INFO: EPOCH 7 - PROGRESS: at 97.53% examples, 1093552 words/s, in_qsize 11, out_qsize 1
# INFO: EPOCH 7: training on 4264099 raw words (2268095 effective words) took 2.1s, 1105435 effective words/s
# INFO: EPOCH 8 - PROGRESS: at 45.45% examples, 1020891 words/s, in_qsize 29, out_qsize 2
# INFO: EPOCH 8 - PROGRESS: at 92.36% examples, 1041494 words/s, in_qsize 31, out_qsize 0
# INFO: EPOCH 8: training on 4264099 raw words (2268005 effective words) took 2.1s, 1060188 effective words/s
# INFO: EPOCH 9 - PROGRESS: at 46.85% examples, 1043614 words/s, in_qsize 31, out_qsize 0
# INFO: EPOCH 9: training on 4264099 raw words (2268500 effective words) took 2.0s, 1134355 effective words/s
# INFO: Word2Vec lifecycle event {'msg': 'training on 42640990 raw words (22679643 effective words) took 21.6s, 1049341 effective words/s', 'datetime': '2024-05-12T10:30:07.949137', 'gensim': '4.3.1', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'train'}
# INFO: Word2Vec lifecycle event {'params': 'Word2Vec<vocab=12564, vector_size=100, alpha=0.025>', 'datetime': '2024-05-12T10:30:07.949137', 'gensim': '4.3.1', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'created'}
# INFO: Time for learning the language model: 22.860950708389282 seconds
# INFO: storing 12564x100 projection weights into ./cache/output/ontology.embeddings.config1.txt
# INFO: Word2Vec lifecycle event {'fname_or_handle': './cache/output/ontology.embeddings.config1', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2024-05-12T10:30:08.652349', 'gensim': '4.3.1', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'saving'}
# INFO: not storing attribute cum_table
# INFO: saved ./cache/output/ontology.embeddings.config1

# %% [markdown]
# ##### Configuration 2

# %%
#Parameters:
# ontology_file
# config_file
# uri_doc
# lit_doc
# mix_doc

#Config 2:
#walker = random
#walk_depth = 1
#URI_Doc = yes
#Lit_Doc = yes
#Mix_Doc = no
#Mix_Type = random
#embed_size = 100
#iteration = 10
#window = 10
#min_count = 1
#negative = 5
#seed = 42
#epoch = 100

gensim_model2 = owl2vec_star.extract_owl2vec_model(
    r"C:\Users\Fasih Munir\Desktop\Knowledge Graphs Final Coursework\OWL2Vec-Star-IN3067-INM713\OWL2Vec-Star-master\ontology_for_embeddings.owl",
    "default_updated_config_2.cfg", True, True, True)

output_folder="./cache/output/"

#one binary and one non binary file
gensim_model2.wv.save_word2vec_format(output_folder+"ontology.embeddings.config2.txt", binary=False)
gensim_model2.save(output_folder+"ontology.embeddings.config2")
# Out:
# INFO: Access the ontology ...
# INFO: There are 6336 triples in the ontology
# INFO: Calculate the ontology projection ...
# INFO: Creating ontology graph projection...
# INFO: 	Extracting subsumption triples
# INFO: 		Time extracting subsumption: 0.11549663543701172 seconds
# INFO: 	Extracting equivalence triples
# INFO: 		Time extracting equivalences: 0.02979445457458496 seconds
# INFO: 	Extracting class membership triples.
# INFO: 		Time extracting class membership: 0.6956355571746826 seconds
# INFO: 	Extracting sameAs triples
# INFO: 		Time extracting sameAs: 0.006412029266357422 seconds
# INFO: 	Extracting triples associated to locatedInCity
# INFO: 		Time extracting triples for property: 0.11785340309143066 seconds
# INFO: 	Extracting triples associated to locatedInAddress
# INFO: 		Time extracting triples for property: 0.10675168037414551 seconds
# INFO: 	Extracting triples associated to serves
# INFO: 		Time extracting triples for property: 0.10326981544494629 seconds
# INFO: 	Extracting triples associated to hasIngredient
# INFO: 		Time extracting triples for property: 0.14861655235290527 seconds
# INFO: 	Extracting triples associated to locatedInState
# INFO: 		Time extracting triples for property: 0.11161589622497559 seconds
# INFO: 	Extracting triples associated to amountCurrency
# INFO: 		Time extracting triples for property: 0.11227679252624512 seconds
# INFO: 	Extracting triples associated to locatedIn
# INFO: 		Time extracting triples for property: 0.09575629234313965 seconds
# INFO: 	Extracting triples associated to isIngredientOf
# INFO: 		Time extracting triples for property: 0.11125564575195312 seconds
# INFO: 	Extracting triples associated to servesMenuItem
# INFO: 		Time extracting triples for property: 0.09813308715820312 seconds
# INFO: 	Extracting triples associated to locatedInCountry
# INFO: 		Time extracting triples for property: 0.10852360725402832 seconds
# INFO: 	Extracting triples associated to containsLocation
# INFO: 		Time extracting triples for property: 0.09720921516418457 seconds
# INFO: 	Extracting triples associated to hasValue
# INFO: 		Time extracting triples for property: 0.10869479179382324 seconds
# INFO: 	Extracting triples associated to containsCity
# INFO: 		Time extracting triples for property: 0.1031038761138916 seconds
# INFO: 	Extracting triples associated to servedIn
# INFO: 		Time extracting triples for property: 0.11281180381774902 seconds
# INFO: 	Extracting triples associated to servedInRestaurant
# INFO: 		Time extracting triples for property: 0.0947577953338623 seconds
# INFO: 	Extracting triples associated to containsAdress
# INFO: 		Time extracting triples for property: 0.0937657356262207 seconds
# INFO: 	Extracting triples associated to containsState
# INFO: 		Time extracting triples for property: 0.09226822853088379 seconds
# INFO: 	Extracting data property assertions
# INFO: 		Time extracting data property assertions: 0.1530449390411377 seconds
# INFO: 	Extracting complex equivalence axioms
# INFO: 		Time extracting complex equivalence axioms: 0.6605806350708008 seconds
# INFO: 	Extracting annotations.
# INFO: 		Time extracting annotations: 0.5494933128356934 seconds
# INFO: Projection created into a Graph object (RDFlib library)
# INFO: Projection saved into turtle file: ./cache/projection.ttl
# INFO: Extract classes and individuals ...
# INFO: Extract axioms ...
# INFO: Extract annotations ...
# INFO: Generate URI document ...
# INFO: Extracted 499 walks for 151 seed entities
# INFO: Extracted 2519 axiom sentences
# INFO: Generate literal document ...
# INFO: Extracted 17 annotation sentences
# INFO: Generate mixture document ...
# INFO: URI_Doc: 3018, Lit_Doc: 3064, Mix_Doc: 3018
# INFO: Time for document construction: 6.756207227706909 seconds
# INFO: Train the language model ...
# INFO: collecting all words and their counts
# INFO: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO: collected 2171 word types from a corpus of 46907 raw words and 9100 sentences
# INFO: Creating a fresh vocabulary
# INFO: Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 2171 unique words (100.00% of original 2171, drops 0)', 'datetime': '2024-05-12T10:30:15.503033', 'gensim': '4.3.1', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'prepare_vocab'}
# INFO: Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 46907 word corpus (100.00% of original 46907, drops 0)', 'datetime': '2024-05-12T10:30:15.505032', 'gensim': '4.3.1', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'prepare_vocab'}
# INFO: deleting the raw counts dictionary of 2171 items
# INFO: sample=0.001 downsamples 62 most-common words
# INFO: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 34458.17975412309 word corpus (73.5%% of prior 46907)', 'datetime': '2024-05-12T10:30:15.516788', 'gensim': '4.3.1', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'prepare_vocab'}
# INFO: estimated required memory for 2171 words and 100 dimensions: 2822300 bytes
# INFO: resetting layer weights
# INFO: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2024-05-12T10:30:15.532744', 'gensim': '4.3.1', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'build_vocab'}
# INFO: Word2Vec lifecycle event {'msg': 'training model with 16 workers on 2171 vocabulary and 100 features, using sg=1 hs=0 sample=0.001 negative=5 window=10 shrink_windows=True', 'datetime': '2024-05-12T10:30:15.532744', 'gensim': '4.3.1', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'train'}
# INFO: EPOCH 0: training on 46907 raw words (34444 effective words) took 0.0s, 1033550 effective words/s
# INFO: EPOCH 1: training on 46907 raw words (34527 effective words) took 0.0s, 1031251 effective words/s
# INFO: EPOCH 2: training on 46907 raw words (34358 effective words) took 0.0s, 1064938 effective words/s
# INFO: EPOCH 3: training on 46907 raw words (34484 effective words) took 0.0s, 1026529 effective words/s
# INFO: EPOCH 4: training on 46907 raw words (34579 effective words) took 0.0s, 1132946 effective words/s
# INFO: EPOCH 5: training on 46907 raw words (34434 effective words) took 0.0s, 1090204 effective words/s
# INFO: EPOCH 6: training on 46907 raw words (34364 effective words) took 0.0s, 1222783 effective words/s
# INFO: EPOCH 7: training on 46907 raw words (34456 effective words) took 0.0s, 1039196 effective words/s
# INFO: EPOCH 8: training on 46907 raw words (34517 effective words) took 0.0s, 1045827 effective words/s
# INFO: EPOCH 9: training on 46907 raw words (34364 effective words) took 0.0s, 1052844 effective words/s
# INFO: Word2Vec lifecycle event {'msg': 'training on 469070 raw words (344527 effective words) took 0.4s, 782010 effective words/s', 'datetime': '2024-05-12T10:30:15.974503', 'gensim': '4.3.1', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'train'}
# INFO: Word2Vec lifecycle event {'params': 'Word2Vec<vocab=2171, vector_size=100, alpha=0.025>', 'datetime': '2024-05-12T10:30:15.974503', 'gensim': '4.3.1', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'created'}
# INFO: Time for learning the language model: 0.4985055923461914 seconds
# INFO: storing 2171x100 projection weights into ./cache/output/ontology.embeddings.config2.txt
# INFO: Word2Vec lifecycle event {'fname_or_handle': './cache/output/ontology.embeddings.config2', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2024-05-12T10:30:16.064082', 'gensim': '4.3.1', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'saving'}
# INFO: not storing attribute cum_table
# INFO: saved ./cache/output/ontology.embeddings.config2

# %% [markdown]
# #### Subtask Vector.2

# %%
#lets load the text files and parse them

import pandas as pd

# %%
file_1 = r"C:\Users\Fasih Munir\Desktop\Knowledge Graphs Final Coursework\OWL2Vec-Star-IN3067-INM713\OWL2Vec-Star-master\cache\output\ontology.embeddings.config1.txt"
file_2 = r"C:\Users\Fasih Munir\Desktop\Knowledge Graphs Final Coursework\OWL2Vec-Star-IN3067-INM713\OWL2Vec-Star-master\cache\output\ontology.embeddings.config2.txt"

# %%
#splitting on the space and checking if it is a digit
#played around with the below documentation
#also making lists as we need to pick words we think will be similar else i would have just passed the lists directly but now reading them
#documentation: https://stackoverflow.com/questions/23051294/python-list-comprehension-for-words-that-do-not-consist-solely-of-digits

file_path = file_1
words_embeddings_config_1 = []

with open(file_path, 'r', encoding='utf-8') as file:
    for line in file:
        words = line.split()
        for word in words:
            if not any(char.isdigit() for char in word):
                words_embeddings_config_1.append(word)

file_path = file_2
words_embeddings_config_2 = []

with open(file_path, 'r', encoding='utf-8') as file:
    for line in file:
        words = line.split()
        for word in words:
            if not any(char.isdigit() for char in word):
                words_embeddings_config_2.append(word)

# %%
words_embeddings_config_1
# Out:
# ['of',
#  'type',
#  'subclassof',
#  'super',
#  'class',
#  'pizza',
#  'ingredient',
#  'in',
#  'has',
#  'is',
#  'label',
#  'located',
#  'city',
#  'food',
#  'restaurant',
#  'address',
#  'served',
#  'chicken',
#  'state',
#  'item',
#  'value',
#  'mushroom',
#  'name',
#  'meat',
#  'location',
#  'menu',
#  'vegan',
#  'sauce',
#  'seafood',
#  'barbecue',
#  'fruit',
#  'pineapple',
#  'hawaiian',
#  'supreme',
#  'feta',
#  'vegetable',
#  'country',
#  'beans',
#  'vegetarian',
#  'pepper',
#  'marinara',
#  'italian',
#  'tomato',
#  'serves',
#  'pepperoni',
#  'altlabel',
#  'bbq',
#  'currency',
#  'amount',
#  'sausage',
#  'pizzeria',
#  'cheese',
#  'mexican',
#  'place',
#  'greek',
#  'by',
#  'onion',
#  'bianca',
#  'us',
#  'mozzarella',
#  'margherita',
#  'funghi',
#  'napolitana',
#  'japanese',
#  'garlic',
#  'meaty',
#  'ham',
#  'basil',
#  'and',
#  'sause',
#  'capers',
#  'bakers',
#  'mellow',
#  'comment',
#  'bar',
#  "\\xbc'",
#  'white',
#  'style',
#  'mediterranean',
#  'grill',
#  'american',
#  'the',
#  "b'@",
#  'olives',
#  'kitchen',
#  'ernesto',
#  "\\xbc'",
#  'olathe',
#  'shop',
#  'coffee',
#  'original',
#  'named',
#  'st',
#  'bars',
#  'anchovies',
#  'bakery',
#  'zios',
#  'green',
#  ',',
#  'clubs',
#  'pubs',
#  'artichoke',
#  'street',
#  'bacon',
#  'sports',
#  'eggplant',
#  'herbs',
#  'beef',
#  'giorgios',
#  'spinach',
#  'buffalo',
#  'parmesan',
#  'Type',
#  'cheddar',
#  'zucchini',
#  'root',
#  'asian',
#  'n',
#  'fig',
#  'greeks',
#  'little',
#  'club',
#  'seeds',
#  'chorizo',
#  'blue',
#  'contains',
#  'squash',
#  'winter',
#  'tuna',
#  'cafe',
#  'rd',
#  'salmon',
#  'salami',
#  'antonios',
#  'meatballs',
#  'dietary',
#  'provolone',
#  'goat',
#  'gourmet',
#  'prosciutto',
#  'cafeteria',
#  'pub',
#  'ave',
#  'broccoli',
#  'sweet',
#  'b',
#  'gorgonzola',
#  'ricotta',
#  'caesars',
#  'johns',
#  "b'",
#  'olive',
#  'oil',
#  'franks',
#  'red',
#  'riccardos',
#  'gardens',
#  'new',
#  'den',
#  'shrimp',
#  'black',
#  'e',
#  'pesto',
#  'yellow',
#  'denver',
#  'hot',
#  'burger',
#  'restaurants',
#  'mortadella',
#  'walnut',
#  'grille',
#  'fire',
#  'pasta',
#  'york',
#  'spicy',
#  'romana',
#  'aubergine',
#  'mexico',
#  's',
#  "\\xdaw/'",
#  'los',
#  'broad',
#  "'",
#  'pancetta',
#  'usd',
#  'giovannis',
#  'hollywood',
#  'tavern',
#  'california',
#  'ninos',
#  'trattoria',
#  "'",
#  'tuscan',
#  "b'",
#  'la',
#  'bravo',
#  'angeles',
#  "b'\\xff",
#  'potato',
#  'steinway',
#  'scallop',
#  'chinese',
#  'fried',
#  'surayas',
#  'deli',
#  'oyster',
#  'joeys',
#  'y',
#  'sushi',
#  'roasted',
#  'deluxe',
#  'bagel',
#  "'",
#  'ca',
#  'tx',
#  "b'",
#  'village',
#  'shore',
#  "z'",
#  'q',
#  'mi',
#  'on',
#  'brentwood',
#  'rivertowne',
#  'north',
#  'fasih',
#  'tofu',
#  'piper',
#  'peter',
#  'french',
#  'everything',
#  'w',
#  'mount',
#  'beer',
#  'viejo',
#  'rancho',
#  'uno',
#  'brandos',
#  'bronson',
#  'fabulous',
#  'euro',
#  'jalapeno',
#  'rica',
#  'casa',
#  'kennebunk',
#  'crab',
#  'ultimate',
#  'indian',
#  'philadelphia',
#  'hacienda',
#  'treat',
#  'parmigiana',
#  "'",
#  "'",
#  'wing',
#  'pa',
#  'plains',
#  "'",
#  'mexicana',
#  'californian',
#  'square',
#  'west',
#  'abos',
#  'crust',
#  'artisan',
#  'verde',
#  "b'",
#  "Z'",
#  "b'\\xff",
#  'ma',
#  'karaoke',
#  'indianapolis',
#  'house',
#  'park',
#  'oh',
#  'alameda',
#  'SubClassOf',
#  'newark',
#  'harrys',
#  'oregano',
#  'enterprise',
#  'homemade',
#  'hunter',
#  'mighty',
#  'township',
#  'rosemary',
#  'main',
#  'austin',
#  'westminster',
#  'dairy-free',
#  "b'",
#  'carrot',
#  'lovers',
#  'nj',
#  'wellington',
#  'providence',
#  'il',
#  'cockeysville',
#  'nutella',
#  'midori',
#  'atheneos',
#  'ny',
#  'san',
#  'lawrence',
#  'zone',
#  'strike',
#  'blvd',
#  'imos',
#  'co',
#  'gastro',
#  'spanish',
#  'kirkland',
#  'saddle',
#  'chatham',
#  'erie',
#  'chester',
#  'saint',
#  'valley',
#  'chicago',
#  'artichokes',
#  'lake',
#  'spokane',
#  'wichita',
#  'milanos',
#  'menifee',
#  'market',
#  'laurel',
#  'river',
#  "b'",
#  'plum',
#  "'",
#  'keller',
#  'grilled',
#  'dr',
#  'pals',
#  'sturbridge',
#  'littleton',
#  'town',
#  'broussard',
#  'beach',
#  'southgate',
#  'md',
#  'pasadena',
#  'butternutsquash',
#  "b'",
#  'mesquite',
#  'omaha',
#  'brook',
#  'danvers',
#  'gluten-free',
#  'scallops',
#  'astoria',
#  'or',
#  'diolis',
#  "b'",
#  'highlands',
#  'newton',
#  'sea',
#  'wa',
#  'some',
#  'henderson',
#  "b'",
#  'bistro',
#  'manhattan',
#  'tons',
#  'drive',
#  'hungry',
#  'arvada',
#  'howies',
#  'paradise',
#  'cocktail',
#  'hickory',
#  'sacramento',
#  'arnold',
#  'phoenix',
#  'americus',
#  'madison',
#  'with',
#  'loveland',
#  'bend',
#  'salem',
#  'winston',
#  'ks',
#  'chandler',
#  'bloomfield',
#  'luzerne',
#  'pumpkin',
#  'lover',
#  'college',
#  "'",
#  'quincy',
#  'mall',
#  'roast',
#  'cherry',
#  "&a'",
#  'minneapolis',
#  'southlake',
#  'englishtown',
#  'doubledaves',
#  'albans',
#  'vernon',
#  'china',
#  'connellsville',
#  'ristorante',
#  'fairbanks',
#  "b'",
#  'larosas',
#  'barboursville',
#  'salernos',
#  'clark',
#  'maitland',
#  'lafayette',
#  'endicott',
#  'houston',
#  'fresno',
#  'southaven',
#  'wyoming',
#  'bloomington',
#  'cincinnati',
#  'memphis',
#  'hyannis',
#  'flushing',
#  'veggie',
#  'urbana',
#  'baltimore',
#  'fairfield',
#  "b'",
#  'osseo',
#  'redford',
#  'thai',
#  'middle',
#  'pine',
#  'cedar',
#  'suffolk',
#  'pizzatm',
#  'addison',
#  'diego',
#  'findlay',
#  'center',
#  'orleans',
#  'hermosa',
#  'grand',
#  'burgers',
#  'irvine',
#  'cupcakes',
#  'prairie',
#  'santa',
#  'cruz',
#  'cove',
#  'nv',
#  'pirates',
#  'de',
#  'gran',
#  'morsi',
#  "b'",
#  'seattle',
#  'queens',
#  'ct',
#  'massapequa',
#  'gina',
#  'marias',
#  'mo',
#  'fl',
#  'glen',
#  'az',
#  "'",
#  'homer',
#  'pl',
#  'station',
#  'ms',
#  'tracy',
#  'bothell',
#  'nyc',
#  'berwyn',
#  "b'",
#  'chestnut',
#  "'",
#  'burlington',
#  'ne',
#  'vegas',
#  'las',
#  "b'\\xbd(",
#  'jose',
#  'forest',
#  'staten',
#  'island',
#  'wine',
#  "^nt'",
#  'union',
#  'inn',
#  "b'n",
#  'foolish',
#  "&A'",
#  'hill',
#  'steak',
#  'road',
#  "b'",
#  'kernersville',
#  'kingsgate',
#  'bethlehem',
#  'langley',
#  'provo',
#  'phila',
#  'harvey',
#  'denville',
#  'mphs',
#  'oldtown',
#  'essex',
#  'fairmont',
#  'grove',
#  'pickens',
#  'dye',
#  'hoboken',
#  'laconia',
#  'me',
#  'own',
#  'piscataway',
#  'wausau',
#  'lawrenceville',
#  'pittsburgh',
#  'wv',
#  'your',
#  'build',
#  'ranch',
#  'longview',
#  'no',
#  'elmhurst',
#  "d'",
#  'sc',
#  'brookline',
#  'queensgate',
#  'columbus',
#  'hammonton',
#  'ga',
#  'wilmington',
#  'kent',
#  'bread',
#  'juanita',
#  'matthewstown',
#  'ak',
#  'gainesville',
#  'meatball',
#  'washington',
#  'hassan',
#  'spring',
#  'heights',
#  'shelton',
#  'va',
#  'truffle',
#  "b'",
#  'crestview',
#  'free',
#  'gluten',
#  'veg',
#  'niguel',
#  'out',
#  'laguna',
#  'ut',
#  'tn',
#  'hunan',
#  'midtown',
#  'murdock',
#  'louis',
#  'connelsvl',
#  'hernando',
#  'dc',
#  'raugust',
#  'ia',
#  'ii',
#  'rosa',
#  'baking',
#  "'",
#  'lahvosh',
#  'ontario',
#  'ross',
#  'foxs',
#  'oven',
#  'austins',
#  'king',
#  'prussia',
#  'mn',
#  'italy',
#  'mediterraneo',
#  'tascalis',
#  'pizzaworks',
#  'decades',
#  'sir',
#  'pitt',
#  'wi',
#  'bostons',
#  'luckys',
#  'cristys',
#  'copelands',
#  'uptown',
#  'carluccios',
#  'cheescake',
#  'stissing',
#  'eaters',
#  'brothers',
#  'francescas',
#  'alaskan',
#  'ming',
#  'chenas',
#  'tony',
#  'marble',
#  "^nT'",
#  'garden',
#  'sopranos',
#  'cliff',
#  'cocktails',
#  'bosses',
#  'prince',
#  'uncle',
#  'russos',
#  'casinos',
#  'veloce',
#  'sioux',
#  'nypd',
#  'brians',
#  'avellinos',
#  'tre',
#  'booies',
#  'jets',
#  'moses',
#  'at',
#  'patrick',
#  'molloys',
#  'gyro',
#  'knollas',
#  'kyoto',
#  'glutenfree',
#  'baldinelli',
#  'things',
#  'taco',
#  'pronto',
#  'alley',
#  'lookout',
#  'crane',
#  'icon',
#  'weirs',
#  'pagliacci',
#  'catering',
#  'sluggers',
#  'kilt',
#  'mission',
#  'louies',
#  'anchor',
#  'university',
#  'moon',
#  'tilted',
#  'roadhouse',
#  'fazolis',
#  'works',
#  'zpizza',
#  'tpke',
#  'feliz',
#  'view',
#  'italiano',
#  'b"',
#  'pkwy',
#  "b'",
#  'ray',
#  "b'n",
#  "b'\\xbd(",
#  'route',
#  'tower',
#  'large',
#  'small',
#  'oakridge',
#  'roll',
#  'combo',
#  "j'",
#  "b's\\xed",
#  "b'",
#  "b'",
#  "b'",
#  "b'\\xfdd",
#  "'",
#  "\\xba\\xae'",
#  "b'`%u",
#  "b'",
#  'b\'k"n{',
#  "D'",
#  'alfredo',
#  'arthichoke',
#  'heart',
#  'regular',
#  'for',
#  'simplicity,',
#  'this',
#  'ontology',
#  'relies',
#  'on',
#  'the',
#  'original',
#  'meaning',
#  'to',
#  'refer',
#  'to',
#  'all',
#  'edible',
#  'plant',
#  'matter,',
#  'including',
#  'the',
#  'flowers,',
#  'fruits,',
#  'stems,',
#  'leaves,',
#  'roots,',
#  'and',
#  'seeds.',
#  'Ingredient',
#  'prima',
#  'equivalentto',
#  'fresh',
#  'young',
#  'brigham',
#  "b'o\\xcc",
#  "b'",
#  'raritan',
#  'gay',
#  "'",
#  'watson',
#  'highland',
#  'm',
#  'fm',
#  'rock',
#  'esperanza',
#  'xing',
#  'englar',
#  'charles',
#  'colfax',
#  'line',
#  'warren',
#  "b'",
#  'cross',
#  'ogletown',
#  'ludlow',
#  'stanton',
#  'goodman',
#  'highway',
#  'reynolda',
#  'eastern',
#  'boat',
#  'post',
#  'forsyth',
#  'whitestone',
#  'pita',
#  'rhyne',
#  'lenoir',
#  'strang',
#  'maple',
#  'church',
#  'eureka',
#  'soquel',
#  'gross',
#  'target',
#  'from',
#  'across',
#  'cascade',
#  'coshocton',
#  'carrier',
#  'south',
#  'newport',
#  'libra',
#  'merrick',
#  'glenway',
#  'emanuel',
#  'metropolitan',
#  'indiana',
#  'orlando',
#  'swift',
#  'jason',
#  'plymouth',
#  'el',
#  'lago',
#  'alton',
#  'madeira',
#  "J'",
#  'nordic',
#  'charlton',
#  'only',
#  'b\'k"n{',
#  'stelton',
#  'longmire',
#  'rio',
#  'del',
#  'camino',
#  'golden',
#  'lantern',
#  'a',
#  'bagels',
#  'Food',
#  'i',
#  'love',
#  'bluff',
#  'kroger',
#  'jct',
#  'pineview',
#  "b's\\xed",
#  '\\xbft`"',
#  'ln',
#  'westgate',
#  'emerson',
#  'wings',
#  'coast',
#  'east',
#  'mos',
#  'eatery',
#  'ann',
#  'gatehouse',
#  'barrington',
#  "b'k",
#  'satsuma',
#  'delaware',
#  "\\xba\\xae'",
#  'patsys',
#  'broadway',
#  'woolworth',
#  'grocery',
#  'ralphs',
#  'kelly',
#  'reserve',
#  'wildcat',
#  '=m',
#  'spagio',
#  'grandview',
#  'naglee',
#  'Vegetable',
#  'applebees',
#  'stewart',
#  'potbelly',
#  'airport',
#  'art',
#  'midway',
#  'sandwich',
#  'subs',
#  'back',
#  'hl',
#  'neck',
#  "\\xcd\\xbbp'",
#  'lakeside',
#  'county',
#  'phillys',
#  "b'",
#  'way',
#  'clayton',
#  'oceano',
#  'd',
#  'vino',
#  'monte',
#  'carlo',
#  'h',
#  'Pizza',
#  'blockbuster',
#  'khans',
#  'mamaroneck',
#  'pot',
#  'melting',
#  'paisans',
#  "b'",
#  'ogden',
#  'spot',
#  'brio',
#  'spud',
#  'plaza',
#  'entrance',
#  'nordstrom',
#  'michaels',
#  'jewish',
#  'delicatessen',
#  'For',
#  'simplicity,',
#  'this',
#  'ontology',
#  'relies',
#  'on',
#  'the',
#  'original',
#  'meaning',
#  'to',
#  'refer',
#  'to',
#  'all',
#  'edible',
#  'plant',
#  'matter,',
#  'including',
#  'the',
#  'flowers,',
#  'fruits,',
#  'stems,',
#  'leaves,',
#  'roots,',
#  'and',
#  'seeds.',
#  'hamilton',
#  'jersey',
#  'buon',
#  'cibo',
#  'mcingvale',
#  'buca',
#  'stratford',
#  'di',
#  'baglianis',
#  'martinizing',
#  "b'`%U",
#  'bowl',
#  'inc',
#  'beppo',
#  'blossom',
#  'organizes',
#  'pizzas',
#  'by',
#  'their',
#  'style',
#  "'",
#  'richmond',
#  'marios',
#  "b'",
#  'six',
#  'pines',
#  'corporate',
#  'adam',
#  'lukes',
#  'harvard',
#  'locker',
#  'swanton',
#  'closed',
#  'pie',
#  'sky',
#  'lineage',
#  'permanently',
#  'scott',
#  'spirits',
#  'gordon',
#  "b'",
#  "'",
#  'charlies',
#  "b'O\\xcc",
#  "'",
#  'EquivalentTo',
#  'keyme',
#  "mr'",
#  "b'",
#  "\\xfc'",
#  'Restaurant',
#  "\\xfc'",
#  'vegan',
#  'ingredient',
#  "'",
#  'rt',
#  'grassfields',
#  "MR'",
#  'Meat',
#  'smoked',
#  'bbq',
#  'sauce',
#  "b'",
#  'fries',
#  'b\'"',
#  'barbecue',
#  'sause',
#  '\\xbfT`"',
#  'Organizes',
#  'pizzas',
#  'by',
#  'their',
#  'style',
#  "'",
#  'organized',
#  'pizzas',
#  'by',
#  'ingredient',
#  "\\xed'",
#  "b'",
#  "b'",
#  "b'",
#  "b'",
#  "b'",
#  'bbq',
#  'pizza',
#  "b'}c",
#  '<class',
#  '=M',
#  'barbecue',
#  'pizza',
#  "b'k",
#  "b'\\\\",
#  'tomato',
#  'sauce',
#  "b'\\xef\\xaa",
#  'b\'"',
#  'Tomato',
#  'sauce',
#  'Vegan',
#  'ingredient',
#  'meat',
#  'pizza',
#  ...]

# %%
words_embeddings_config_2
# Out:
# ['pizza',
#  'type',
#  'in',
#  'Type',
#  'located',
#  'us',
#  'ingredient',
#  'city',
#  'of',
#  'chicken',
#  'name',
#  'subclassof',
#  'restaurant',
#  'address',
#  'has',
#  'state',
#  'mushroom',
#  'is',
#  'pizzeria',
#  'item',
#  'SubClassOf',
#  'value',
#  'label',
#  'st',
#  'usd',
#  'currency',
#  'amount',
#  'the',
#  'and',
#  'italian',
#  'country',
#  'bakers',
#  'mellow',
#  'grill',
#  'served',
#  'mexican',
#  'serves',
#  'supreme',
#  'greek',
#  'rd',
#  'some',
#  'kitchen',
#  'meat',
#  'n',
#  'ave',
#  'olathe',
#  'original',
#  'new',
#  'e',
#  'cafe',
#  'giorgios',
#  'york',
#  'los',
#  'street',
#  'hawaiian',
#  's',
#  'den',
#  'greeks',
#  'zios',
#  'bar',
#  'cheese',
#  'tx',
#  'ca',
#  'pepper',
#  'little',
#  'angeles',
#  'place',
#  'buffalo',
#  'denver',
#  'bbq',
#  'mozzarella',
#  'fire',
#  'antonios',
#  'onion',
#  'vegetable',
#  'village',
#  'mi',
#  'mount',
#  'vegan',
#  'white',
#  'pub',
#  'philadelphia',
#  'sauce',
#  'pepperoni',
#  'seafood',
#  'pasta',
#  'marinara',
#  'tomato',
#  'brentwood',
#  'bronson',
#  'class',
#  'super',
#  'w',
#  'pa',
#  'johns',
#  'green',
#  'kennebunk',
#  'plains',
#  'sports',
#  'la',
#  'walnut',
#  'ma',
#  'olives',
#  'caesars',
#  'giovannis',
#  'grille',
#  'barbecue',
#  'alameda',
#  'beef',
#  'township',
#  'newark',
#  'oh',
#  'indianapolis',
#  'westminster',
#  'park',
#  'deli',
#  'bakery',
#  'franks',
#  'trattoria',
#  'ninos',
#  'garlic',
#  'or',
#  'basil',
#  'uno',
#  'steinway',
#  'bagel',
#  'vegetarian',
#  'riccardos',
#  'kirkland',
#  'il',
#  'california',
#  'food',
#  'fig',
#  'hollywood',
#  'erie',
#  'bacon',
#  'main',
#  'on',
#  'austin',
#  'cockeysville',
#  'house',
#  'gardens',
#  'lawrence',
#  'wichita',
#  'keller',
#  'abos',
#  'west',
#  'wellington',
#  'nj',
#  'bianca',
#  'valley',
#  'pineapple',
#  'atheneos',
#  'joeys',
#  'ny',
#  'by',
#  'y',
#  'spokane',
#  'bravo',
#  'laurel',
#  'md',
#  'tavern',
#  'broad',
#  'chatham',
#  'mesquite',
#  'chicago',
#  'blvd',
#  'fruit',
#  'co',
#  'lake',
#  'san',
#  'sturbridge',
#  'saddle',
#  'club',
#  'menifee',
#  'japanese',
#  'equivalentto',
#  'artichoke',
#  'peter',
#  'providence',
#  'viejo',
#  'piper',
#  'littleton',
#  'mexico',
#  'rancho',
#  'parmesan',
#  'deluxe',
#  'beach',
#  'blue',
#  'sushi',
#  'feta',
#  'fasih',
#  'astoria',
#  'tuscan',
#  'danvers',
#  'town',
#  'altlabel',
#  'black',
#  'pasadena',
#  'b',
#  'casa',
#  'roasted',
#  'saint',
#  'luzerne',
#  'sacramento',
#  'arvada',
#  'rica',
#  'bloomfield',
#  'milanos',
#  'hickory',
#  'oyster',
#  'brook',
#  'southgate',
#  'dr',
#  'broussard',
#  'cheddar',
#  'wa',
#  'fabulous',
#  'crust',
#  'manhattan',
#  'verde',
#  'strike',
#  'pals',
#  'zone',
#  'loveland',
#  'artisan',
#  'only',
#  'menu',
#  'phoenix',
#  'arnold',
#  'americus',
#  'salem',
#  'winston',
#  'shore',
#  'henderson',
#  'college',
#  'chester',
#  'ham',
#  'imos',
#  'omaha',
#  'margherita',
#  'beans',
#  'brandos',
#  'euro',
#  'fried',
#  'surayas',
#  'bend',
#  'endicott',
#  'minneapolis',
#  'ristorante',
#  'gourmet',
#  'memphis',
#  'market',
#  'hyannis',
#  'redford',
#  'ks',
#  'clark',
#  'maitland',
#  'bistro',
#  'doubledaves',
#  'chandler',
#  'river',
#  'location',
#  'madison',
#  'wyoming',
#  'fresno',
#  'suffolk',
#  'pesto',
#  'connellsville',
#  'englishtown',
#  'barboursville',
#  'sea',
#  'irvine',
#  'flushing',
#  'fairbanks',
#  'osseo',
#  'north',
#  'rivertowne',
#  'highlands',
#  'newton',
#  'houston',
#  'drive',
#  'tons',
#  'mall',
#  'EquivalentTo',
#  'southaven',
#  'chorizo',
#  'hacienda',
#  'baltimore',
#  'station',
#  'american',
#  'findlay',
#  'addison',
#  'vernon',
#  'china',
#  'quincy',
#  'salernos',
#  'paradise',
#  'gina',
#  'marias',
#  'fairfield',
#  'spinach',
#  'bloomington',
#  'urbana',
#  'lafayette',
#  'diolis',
#  'roast',
#  'az',
#  'pine',
#  'larosas',
#  'chinese',
#  'mo',
#  'hermosa',
#  'morsi',
#  'gran',
#  'style',
#  'cincinnati',
#  'red',
#  'pirates',
#  'cove',
#  'santa',
#  'cruz',
#  'cedar',
#  'grand',
#  'diego',
#  'seattle',
#  'fl',
#  'spicy',
#  ',',
#  'middle',
#  'homer',
#  'prairie',
#  'glen',
#  'ultimate',
#  'potato',
#  'ct',
#  'nv',
#  'massapequa',
#  'sausage',
#  'center',
#  'queens',
#  'pl',
#  'eggplant',
#  'hungry',
#  'square',
#  'howies',
#  'tracy',
#  'everything',
#  'southlake',
#  'sweet',
#  'de',
#  'burlington',
#  'kingsgate',
#  'albans',
#  'chestnut',
#  'shop',
#  'hot',
#  'tuna',
#  'ms',
#  'wv',
#  'bars',
#  'salami',
#  'orleans',
#  'berwyn',
#  'nyc',
#  'bothell',
#  'mn',
#  'oldtown',
#  'phila',
#  'longview',
#  'mexicana',
#  'forest',
#  'va',
#  'meatballs',
#  'spring',
#  'provolone',
#  'road',
#  '<class',
#  'ne',
#  'oil',
#  'olive',
#  'kernersville',
#  'wing',
#  'me',
#  'inn',
#  'laconia',
#  'harvey',
#  'salmon',
#  'q',
#  'mphs',
#  'grove',
#  'shrimp',
#  'wine',
#  'sc',
#  'fairmont',
#  'ga',
#  'gainesville',
#  'staten',
#  'island',
#  'denville',
#  'parmigiana',
#  'murdock',
#  'italy',
#  'raugust',
#  'hernando',
#  'matthewstown',
#  'union',
#  'ak',
#  'columbus',
#  'jose',
#  'zucchini',
#  'hammonton',
#  'californian',
#  'ut',
#  'enterprise',
#  'sopranos',
#  'tony',
#  'las',
#  'vegas',
#  'cristys',
#  'gorgonzola',
#  'pickens',
#  'elmhurst',
#  'lawrenceville',
#  'queensgate',
#  'prosciutto',
#  'bethlehem',
#  'juanita',
#  'carluccios',
#  'capers',
#  'foolish',
#  'oven',
#  'feliz',
#  'wausau',
#  'ontario',
#  'mediterraneo',
#  'russos',
#  'midori',
#  'kent',
#  'sluggers',
#  'dc',
#  'washington',
#  'prince',
#  'langley',
#  'uptown',
#  'stissing',
#  'hill',
#  'mediterranean',
#  'pittsburgh',
#  'goat',
#  'yellow',
#  'luckys',
#  'coffee',
#  'connelsvl',
#  'rosa',
#  'ii',
#  'pronto',
#  'taco',
#  'pitt',
#  'lahvosh',
#  'sause',
#  'midtown',
#  'hoboken',
#  'bosses',
#  'knollas',
#  'veloce',
#  'hunter',
#  'nutella',
#  'chenas',
#  'hassan',
#  'pizzaworks',
#  'alaskan',
#  'baking',
#  'at',
#  'squash',
#  'piscataway',
#  'tascalis',
#  'brothers',
#  'decades',
#  'bostons',
#  'prussia',
#  'essex',
#  'booies',
#  'king',
#  'shelton',
#  'works',
#  'glutenfree',
#  'things',
#  'dietary',
#  'pagliacci',
#  'wilmington',
#  'provo',
#  'uncle',
#  "'str'>",
#  'roadhouse',
#  'jets',
#  'alley',
#  'crane',
#  'italiano',
#  'molloys',
#  'lookout',
#  'with',
#  'kyoto',
#  'clubs',
#  'casinos',
#  'pubs',
#  'pkwy',
#  'patrick',
#  'oregano',
#  'nypd',
#  'cocktails',
#  'tn',
#  'brians',
#  'ia',
#  'view',
#  'francescas',
#  'austins',
#  'mission',
#  'kilt',
#  'tilted',
#  'anchor',
#  'baldinelli',
#  'ming',
#  'beer',
#  'wi',
#  'garden',
#  'french',
#  'ross',
#  'ricotta',
#  'catering',
#  'treat',
#  'crestview',
#  'heights',
#  'moses',
#  'napolitana',
#  'brookline',
#  'herbs',
#  'gyro',
#  'louies',
#  'seeds',
#  'sioux',
#  'tre',
#  'ray',
#  'artichokes',
#  'jalapeno',
#  'sir',
#  'cheescake',
#  'rosemary',
#  'thai',
#  'avellinos',
#  'named',
#  'veggie',
#  'harrys',
#  'hunan',
#  'cupcakes',
#  'burgers',
#  'foxs',
#  'fazolis',
#  'louis',
#  'weirs',
#  'winter',
#  'tpke',
#  'moon',
#  'copelands',
#  'zpizza',
#  'plum',
#  'root',
#  'romana',
#  'steak',
#  'broccoli',
#  'laguna',
#  'niguel',
#  'grilled',
#  'asian',
#  'lover',
#  'mighty',
#  'anchovies',
#  'no',
#  'cliff',
#  'marble',
#  'tower',
#  'karaoke',
#  'mortadella',
#  'lovers',
#  'burger',
#  'gastro',
#  'university',
#  'oakridge',
#  'carrot',
#  'scallop',
#  'icon',
#  'homemade',
#  'indian',
#  'butternutsquash',
#  'http://www.co-ode.org/ontologies/pizza/pizza.owl#Country',
#  'lenoir',
#  'rhyne',
#  'adam',
#  'scott',
#  'route',
#  'combo',
#  'rock',
#  'swift',
#  'jason',
#  'ernesto',
#  'libra',
#  'indiana',
#  'rio',
#  'del',
#  'camino',
#  'esperanza',
#  'newport',
#  'plymouth',
#  'post',
#  'meaty',
#  'line',
#  'emanuel',
#  'prima',
#  'reynolda',
#  'county',
#  'maple',
#  'cascade',
#  'm',
#  'carrier',
#  'across',
#  'from',
#  'cocktail',
#  'target',
#  'kelly',
#  'own',
#  'roll',
#  'church',
#  'xing',
#  'your',
#  'build',
#  'madeira',
#  'funghi',
#  'englar',
#  'cafeteria',
#  'eureka',
#  'large',
#  'boat',
#  'nordic',
#  'eaters',
#  'whitestone',
#  'colfax',
#  'charlton',
#  'a',
#  'longmire',
#  'aubergine',
#  'ranch',
#  'pancetta',
#  'merrick',
#  'forsyth',
#  'warren',
#  'cherry',
#  'fm',
#  'comment',
#  'heart',
#  'soquel',
#  'regular',
#  'restaurants',
#  'gross',
#  'scallops',
#  'arthichoke',
#  'truffle',
#  'dye',
#  'emerson',
#  'pita',
#  'raritan',
#  'young',
#  'brigham',
#  'metropolitan',
#  'barrington',
#  'watson',
#  'el',
#  'alton',
#  'coshocton',
#  'highland',
#  'pizzatm',
#  'gay',
#  'alfredo',
#  'lago',
#  'meatball',
#  'bowl',
#  'glenway',
#  'pines',
#  'six',
#  'locker',
#  'lukes',
#  'cross',
#  'stanton',
#  'ogletown',
#  'ln',
#  'pineview',
#  'melting',
#  'pot',
#  'mamaroneck',
#  'veg',
#  'goodman',
#  'out',
#  'inc',
#  'monte',
#  'stelton',
#  'd',
#  'vino',
#  'carlo',
#  'back',
#  'michaels',
#  'delicatessen',
#  'jewish',
#  'woolworth',
#  'broadway',
#  'neck',
#  'free',
#  'charles',
#  'stratford',
#  'gluten',
#  'bread',
#  'dairy-free',
#  'south',
#  'ralphs',
#  'grocery',
#  'orlando',
#  'blockbuster',
#  'oceano',
#  'clayton',
#  'keyme',
#  'baglianis',
#  'airport',
#  'midway',
#  'sandwich',
#  'potbelly',
#  'blossom',
#  'crab',
#  'nordstrom',
#  'beppo',
#  'di',
#  'bluff',
#  'kroger',
#  'jct',
#  'buca',
#  'lakeside',
#  'entrance',
#  'coast',
#  'highway',
#  'eastern',
#  'applebees',
#  'east',
#  'spud',
#  'strang',
#  'spot',
#  'naglee',
#  'wings',
#  'gluten-free',
#  'small',
#  'spanish',
#  'mcingvale',
#  'contains',
#  'newton_highlands',
#  'mi_pals_deli_philadelphia',
#  'austins_pizza_austin',
#  'west_river_cafe_providence',
#  'gran_morsi_new_york',
#  'larosas_pizzeria_loveland',
#  'ristorante_italiano_santa_cruz',
#  'nypd_pizza_maitland',
#  'supreme_roast_beef_sea_food_danvers',
#  "'float'>",
#  'martinizing',
#  'lawrence_township',
#  'tre_restaurant_wine_bar_new_york',
#  'blue_anchor',
#  'delaware',
#  'massapequa_park',
#  'buon',
#  'uncle_johns_pizza_grand_prairie',
#  'valley_lahvosh_baking_fresno',
#  'satsuma',
#  'atheneos_greek_village_cafe_mesquite',
#  'grassfields',
#  'walnut_grille_newton_highlands',
#  'mount_ross',
#  'westgate',
#  'diolis_italian_market_winston_salem',
#  'steinway_pizza_astoria',
#  'kyoto_sushi_flushing',
#  'original_giorgios_cockeysville',
#  'cibo',
#  'franks_pizzeria_omaha',
#  'white_lake',
#  'roadhouse_cafe_hyannis',
#  'kennebunk_house_of_pizza_kennebunk',
#  'zpizza_irvine',
#  'crane_alley_urbana',
#  'corporate',
#  'bronson_strike_zone_bronson',
#  'las_vegas',
#  'the_lookout_catering_osseo',
#  'avellinos_pizza_southaven',
#  'middle_village',
#  'jets_pizza_white_lake',
#  'carluccios_philadelphia',
#  'tofu',
#  'rancho_viejo_mexican_grill_hickory',
#  'way',
#  'permanently',
#  'ogden',
#  'hl',
#  'paisans',
#  'hermosa_beach',
#  'ann',
#  'gatehouse',
#  'giovannis_pizza_and_pasta_menifee',
#  'pumpkin',
#  'sioux_city',
#  'king_of_prussia',
#  'bosses_pizza_keller_keller',
#  'euro_pizzeria_white_plains',
#  'lineage',
#  'closed',
#  'pine_plains',
#  'st_albans',
#  'tilted_kilt_mission_valley_san_diego',
#  'winston_salem',
#  'homer_glen',
#  'gina_marias_pizza_minneapolis',
#  'reserve',
#  'ming_garden_cocktails_chinese_restaurant_newark',
#  'white_plains',
#  'larosas_pizzeria_cincinnati',
#  'little_italy_pizza_memphis',
#  'los_angeles',
#  'california_pizza_kitchen_wellington',
#  'lantern',
#  'golden',
#  'bagels',
#  'love',
#  'i',
#  'little_caesars_pizza_pasadena',
#  'quincy_center',
#  'harvard',
#  'rosa_ii_pizzeria_restaurant_middle_village',
#  'tascalis_decades_pasta_grill_barboursville',
#  'prince_pizza_redford',
#  'greeks_pizzeria_indianapolis',
#  'gordon',
#  'spirits',
#  'charlies',
#  'brandos_pizza_buffalo',
#  'foolish_fasih_pizza_los_angeles',
#  'louies_pizza_newark',
#  'weirs_beach',
#  'doubledaves_pizzaworks_cedar_park',
#  'crestview_heights',
#  'rt',
#  'peter_piper_pizza_phoenix',
#  'hunan_gourmet_englishtown',
#  'cedar_park',
#  'patrick_molloys_sports_pub_hermosa_beach',
#  'grand_prairie',
#  'country_bagel_bakery_west_chester',
#  'riccardos_pizza_saddle_brook',
#  'saint_louis',
#  'taco_pronto_wichita',
#  'pirates_cove_mount_vernon',
#  'luckys_pub_houston',
#  'milanos_pizza_sacramento',
#  'doubledaves_pizza_works_college_station',
#  'laguna_niguel',
#  'antonios_pizza_chatham',
#  'ninos_trattoria_pizzeria_lawrence_township',
#  'pagliacci_pizza_kirkland',
#  'hamilton',
#  'glutenfree_things_arvada',
#  'moses_lake',
#  'mount_vernon',
#  'fazolis_bloomington',
#  'saint_albans',
#  'wildcat',
#  'baldinelli_pizza_homer_glen',
#  'casinos_pizza_addison',
#  'mediterraneo_ristorante_westminster',
#  'mount_laurel',
#  'marble_cliff',
#  'copelands_cheescake_bistro_new_orleans',
#  'mexican_gardens_southgate',
#  'the_italian_oven_connellsville',
#  'sluggers_sports_bar_erie',
#  'forest_view',
#  'the_brentwood_los_angeles',
#  'san_jose',
#  'tony_sopranos_pizza_mount_laurel',
#  'imos_pizza_arnold',
#  'new_york_city',
#  'russos_pizza_wyoming',
#  'sir_pizza_madison',
#  'china_kitchen_denver',
#  'art',
#  'college_station',
#  'la_hacienda_americus',
#  'ontario_street',
#  'richmond',
#  'salernos_pizza_restaurant_luzerne',
#  'abos_pizza_littleton',
#  'tons_drive_in_broussard',
#  'marios',
#  'foxs_pizza_den_lafayette',
#  'oh_brians_on_the_green_clark',
#  'patsys',
#  'khans',
#  'h',
#  'stissing_house_pine_plains',
#  'mount_laurel_township',
#  'pizza_bistro_massapequa_park',
#  'new_york',
#  'bostons_restaurant_sports_bar_spokane',
#  'mellow_mushroom_pizza_bakers_denver',
#  'staten_island',
#  'village_of_wellington',
#  'jersey',
#  'little_pizza_paradise_bend',
#  'san_diego',
#  'plaza',
#  'saddle_brook',
#  'santa_cruz',
#  'cristys_pizza_baltimore',
#  'tomato_basil_fairfield',
#  'ludlow',
#  'chenas_alaskan_grill_fairbanks',
#  'grandview',
#  'spagio',
#  'joeys_n_y_pizza_henderson',
#  'los_feliz',
#  'cafe_veloce_kirkland',
#  'brio',
#  'the_fire_den_alameda',
#  'city_of_spokane_valley',
#  'china_moon_suffolk',
#  'california_pizza_kitchen_austin',
#  'town_pub_bloomfield',
#  'casa_rica_westminster',
#  'zios_italian_kitchen_olathe_olathe',
#  'uno_pizzeria_grill_sturbridge_sturbridge',
#  'new_orleans',
#  'no_providence',
#  'booies_pizza_erie',
#  'francescas_on_chestnut_chicago',
#  'knollas_pizza_wichita',
#  'hungry_howies_pizza_chandler',
#  'fabulous_fasih_pizza_los_angeles',
#  'west_chester',
#  'bravo_pizza_hollywood_los_angeles',
#  's_connelsvl',
#  'tavern_at_the_inn_findlay',
#  'pie',
#  'swanton',
#  'sky',
#  'england',
#  'http://www.co-ode.org/ontologies/pizza/pizza.owl#America',
#  'subs',
#  'stewart',
#  'eatery',
#  'phillys',
#  'to',
#  'relies',
#  'ontology',
#  'this',
#  'simplicity',
#  'for',
#  '.',
#  'dip',
#  'not(c:\\users\\fasih',
#  'munir\\desktop\\knowledge',
#  'graphs',
#  'final',
#  'mos',
#  'first',
#  'pizzas',
#  'http://www.co-ode.org/ontologies/pizza/pizza.owl#Germany',
#  'france',
#  'smoked',
#  'butternut',
#  'language',
#  "''",
#  '(',
#  '``',
#  'usage',
#  'http://www.co-ode.org/ontologies/pizza/pizza.owl#France',
#  'common',
#  'germany',
#  'http://www.co-ode.org/ontologies/pizza/pizza.owl#England',
#  'edible',
#  'america',
#  'without',
#  'fresh',
#  'code',
#  'roots',
#  'leaves',
#  'stems',
#  ...]

# %% [markdown]
# ##### Subtask Vector.2.1
#
# similariteis for the first configuration

# %%
#Embedding vectors generated above
model1 = KeyedVectors.load(r"C:\Users\Fasih Munir\Desktop\Knowledge Graphs Final Coursework\OWL2Vec-Star-IN3067-INM713\OWL2Vec-Star-master\cache\output\ontology.embeddings.config1"
                           ,mmap='r')
wv1 = model1.wv

#cosine similarity

#expect to be similar
similarity1 = wv1.similarity('pizza', 'ingredient')
similarity2 = wv1.similarity('pizza', 'food')
similarity3 = wv1.similarity('fruit', 'pineapple')

#expect to be dissimilar
similarity4 = wv1.similarity('meat', 'seafood')
similarity5 = wv1.similarity('cheese', 'currency')
similarity6 = wv1.similarity('salmon', 'seeds')

print('Expect to be Similar')
print(f"The cosine similarity between 'pizza' and 'ingredient' is {similarity1:.3f}")
print(f"The cosine similarity between 'pizza' and 'food' is {similarity2:.3f}")
print(f"The cosine similarity between 'fruit' and 'pineapple' is {similarity3:.3f}")
print('----------------------------')
print('Expect to be Not Similar')
print(f"The cosine similarity between 'meat' and 'seafood' is {similarity4:.3f}")
print(f"The cosine similarity between 'cheese' and 'currency' is {similarity5:.3f}")
print(f"The cosine similarity between 'salmon' and 'seeds' is {similarity6:.3f}")
# Out:
# INFO: loading KeyedVectors object from C:\Users\Fasih Munir\Desktop\Knowledge Graphs Final Coursework\OWL2Vec-Star-IN3067-INM713\OWL2Vec-Star-master\cache\output\ontology.embeddings.config1
# INFO: loading wv recursively from C:\Users\Fasih Munir\Desktop\Knowledge Graphs Final Coursework\OWL2Vec-Star-IN3067-INM713\OWL2Vec-Star-master\cache\output\ontology.embeddings.config1.wv.* with mmap=r
# INFO: setting ignored attribute cum_table to None
# INFO: Word2Vec lifecycle event {'fname': 'C:\\Users\\Fasih Munir\\Desktop\\Knowledge Graphs Final Coursework\\OWL2Vec-Star-IN3067-INM713\\OWL2Vec-Star-master\\cache\\output\\ontology.embeddings.config1', 'datetime': '2024-05-12T10:30:17.302633', 'gensim': '4.3.1', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'loaded'}
# Expect to be Similar
# The cosine similarity between 'pizza' and 'ingredient' is 0.591
# The cosine similarity between 'pizza' and 'food' is 0.632
# The cosine similarity between 'fruit' and 'pineapple' is 0.785
# ----------------------------
# Expect to be Not Similar
# The cosine similarity between 'meat' and 'seafood' is 0.596
# The cosine similarity between 'cheese' and 'currency' is 0.128
# The cosine similarity between 'salmon' and 'seeds' is 0.408

# %% [markdown]
# ##### Subtask Vector.2.2
#
# similarities for the second configuration

# %%
model2 = KeyedVectors.load(r"C:\Users\Fasih Munir\Desktop\Knowledge Graphs Final Coursework\OWL2Vec-Star-IN3067-INM713\OWL2Vec-Star-master\cache\output\ontology.embeddings.config2"
                           ,mmap='r')
wv2 = model2.wv
# Out:
# INFO: loading KeyedVectors object from C:\Users\Fasih Munir\Desktop\Knowledge Graphs Final Coursework\OWL2Vec-Star-IN3067-INM713\OWL2Vec-Star-master\cache\output\ontology.embeddings.config2
# INFO: loading wv recursively from C:\Users\Fasih Munir\Desktop\Knowledge Graphs Final Coursework\OWL2Vec-Star-IN3067-INM713\OWL2Vec-Star-master\cache\output\ontology.embeddings.config2.wv.* with mmap=r
# INFO: setting ignored attribute cum_table to None
# INFO: Word2Vec lifecycle event {'fname': 'C:\\Users\\Fasih Munir\\Desktop\\Knowledge Graphs Final Coursework\\OWL2Vec-Star-IN3067-INM713\\OWL2Vec-Star-master\\cache\\output\\ontology.embeddings.config2', 'datetime': '2024-05-12T10:30:17.331147', 'gensim': '4.3.1', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'loaded'}

# %%
words_embeddings_config_2
# Out:
# ['pizza',
#  'type',
#  'in',
#  'Type',
#  'located',
#  'us',
#  'ingredient',
#  'city',
#  'of',
#  'chicken',
#  'name',
#  'subclassof',
#  'restaurant',
#  'address',
#  'has',
#  'state',
#  'mushroom',
#  'is',
#  'pizzeria',
#  'item',
#  'SubClassOf',
#  'value',
#  'label',
#  'st',
#  'usd',
#  'currency',
#  'amount',
#  'the',
#  'and',
#  'italian',
#  'country',
#  'bakers',
#  'mellow',
#  'grill',
#  'served',
#  'mexican',
#  'serves',
#  'supreme',
#  'greek',
#  'rd',
#  'some',
#  'kitchen',
#  'meat',
#  'n',
#  'ave',
#  'olathe',
#  'original',
#  'new',
#  'e',
#  'cafe',
#  'giorgios',
#  'york',
#  'los',
#  'street',
#  'hawaiian',
#  's',
#  'den',
#  'greeks',
#  'zios',
#  'bar',
#  'cheese',
#  'tx',
#  'ca',
#  'pepper',
#  'little',
#  'angeles',
#  'place',
#  'buffalo',
#  'denver',
#  'bbq',
#  'mozzarella',
#  'fire',
#  'antonios',
#  'onion',
#  'vegetable',
#  'village',
#  'mi',
#  'mount',
#  'vegan',
#  'white',
#  'pub',
#  'philadelphia',
#  'sauce',
#  'pepperoni',
#  'seafood',
#  'pasta',
#  'marinara',
#  'tomato',
#  'brentwood',
#  'bronson',
#  'class',
#  'super',
#  'w',
#  'pa',
#  'johns',
#  'green',
#  'kennebunk',
#  'plains',
#  'sports',
#  'la',
#  'walnut',
#  'ma',
#  'olives',
#  'caesars',
#  'giovannis',
#  'grille',
#  'barbecue',
#  'alameda',
#  'beef',
#  'township',
#  'newark',
#  'oh',
#  'indianapolis',
#  'westminster',
#  'park',
#  'deli',
#  'bakery',
#  'franks',
#  'trattoria',
#  'ninos',
#  'garlic',
#  'or',
#  'basil',
#  'uno',
#  'steinway',
#  'bagel',
#  'vegetarian',
#  'riccardos',
#  'kirkland',
#  'il',
#  'california',
#  'food',
#  'fig',
#  'hollywood',
#  'erie',
#  'bacon',
#  'main',
#  'on',
#  'austin',
#  'cockeysville',
#  'house',
#  'gardens',
#  'lawrence',
#  'wichita',
#  'keller',
#  'abos',
#  'west',
#  'wellington',
#  'nj',
#  'bianca',
#  'valley',
#  'pineapple',
#  'atheneos',
#  'joeys',
#  'ny',
#  'by',
#  'y',
#  'spokane',
#  'bravo',
#  'laurel',
#  'md',
#  'tavern',
#  'broad',
#  'chatham',
#  'mesquite',
#  'chicago',
#  'blvd',
#  'fruit',
#  'co',
#  'lake',
#  'san',
#  'sturbridge',
#  'saddle',
#  'club',
#  'menifee',
#  'japanese',
#  'equivalentto',
#  'artichoke',
#  'peter',
#  'providence',
#  'viejo',
#  'piper',
#  'littleton',
#  'mexico',
#  'rancho',
#  'parmesan',
#  'deluxe',
#  'beach',
#  'blue',
#  'sushi',
#  'feta',
#  'fasih',
#  'astoria',
#  'tuscan',
#  'danvers',
#  'town',
#  'altlabel',
#  'black',
#  'pasadena',
#  'b',
#  'casa',
#  'roasted',
#  'saint',
#  'luzerne',
#  'sacramento',
#  'arvada',
#  'rica',
#  'bloomfield',
#  'milanos',
#  'hickory',
#  'oyster',
#  'brook',
#  'southgate',
#  'dr',
#  'broussard',
#  'cheddar',
#  'wa',
#  'fabulous',
#  'crust',
#  'manhattan',
#  'verde',
#  'strike',
#  'pals',
#  'zone',
#  'loveland',
#  'artisan',
#  'only',
#  'menu',
#  'phoenix',
#  'arnold',
#  'americus',
#  'salem',
#  'winston',
#  'shore',
#  'henderson',
#  'college',
#  'chester',
#  'ham',
#  'imos',
#  'omaha',
#  'margherita',
#  'beans',
#  'brandos',
#  'euro',
#  'fried',
#  'surayas',
#  'bend',
#  'endicott',
#  'minneapolis',
#  'ristorante',
#  'gourmet',
#  'memphis',
#  'market',
#  'hyannis',
#  'redford',
#  'ks',
#  'clark',
#  'maitland',
#  'bistro',
#  'doubledaves',
#  'chandler',
#  'river',
#  'location',
#  'madison',
#  'wyoming',
#  'fresno',
#  'suffolk',
#  'pesto',
#  'connellsville',
#  'englishtown',
#  'barboursville',
#  'sea',
#  'irvine',
#  'flushing',
#  'fairbanks',
#  'osseo',
#  'north',
#  'rivertowne',
#  'highlands',
#  'newton',
#  'houston',
#  'drive',
#  'tons',
#  'mall',
#  'EquivalentTo',
#  'southaven',
#  'chorizo',
#  'hacienda',
#  'baltimore',
#  'station',
#  'american',
#  'findlay',
#  'addison',
#  'vernon',
#  'china',
#  'quincy',
#  'salernos',
#  'paradise',
#  'gina',
#  'marias',
#  'fairfield',
#  'spinach',
#  'bloomington',
#  'urbana',
#  'lafayette',
#  'diolis',
#  'roast',
#  'az',
#  'pine',
#  'larosas',
#  'chinese',
#  'mo',
#  'hermosa',
#  'morsi',
#  'gran',
#  'style',
#  'cincinnati',
#  'red',
#  'pirates',
#  'cove',
#  'santa',
#  'cruz',
#  'cedar',
#  'grand',
#  'diego',
#  'seattle',
#  'fl',
#  'spicy',
#  ',',
#  'middle',
#  'homer',
#  'prairie',
#  'glen',
#  'ultimate',
#  'potato',
#  'ct',
#  'nv',
#  'massapequa',
#  'sausage',
#  'center',
#  'queens',
#  'pl',
#  'eggplant',
#  'hungry',
#  'square',
#  'howies',
#  'tracy',
#  'everything',
#  'southlake',
#  'sweet',
#  'de',
#  'burlington',
#  'kingsgate',
#  'albans',
#  'chestnut',
#  'shop',
#  'hot',
#  'tuna',
#  'ms',
#  'wv',
#  'bars',
#  'salami',
#  'orleans',
#  'berwyn',
#  'nyc',
#  'bothell',
#  'mn',
#  'oldtown',
#  'phila',
#  'longview',
#  'mexicana',
#  'forest',
#  'va',
#  'meatballs',
#  'spring',
#  'provolone',
#  'road',
#  '<class',
#  'ne',
#  'oil',
#  'olive',
#  'kernersville',
#  'wing',
#  'me',
#  'inn',
#  'laconia',
#  'harvey',
#  'salmon',
#  'q',
#  'mphs',
#  'grove',
#  'shrimp',
#  'wine',
#  'sc',
#  'fairmont',
#  'ga',
#  'gainesville',
#  'staten',
#  'island',
#  'denville',
#  'parmigiana',
#  'murdock',
#  'italy',
#  'raugust',
#  'hernando',
#  'matthewstown',
#  'union',
#  'ak',
#  'columbus',
#  'jose',
#  'zucchini',
#  'hammonton',
#  'californian',
#  'ut',
#  'enterprise',
#  'sopranos',
#  'tony',
#  'las',
#  'vegas',
#  'cristys',
#  'gorgonzola',
#  'pickens',
#  'elmhurst',
#  'lawrenceville',
#  'queensgate',
#  'prosciutto',
#  'bethlehem',
#  'juanita',
#  'carluccios',
#  'capers',
#  'foolish',
#  'oven',
#  'feliz',
#  'wausau',
#  'ontario',
#  'mediterraneo',
#  'russos',
#  'midori',
#  'kent',
#  'sluggers',
#  'dc',
#  'washington',
#  'prince',
#  'langley',
#  'uptown',
#  'stissing',
#  'hill',
#  'mediterranean',
#  'pittsburgh',
#  'goat',
#  'yellow',
#  'luckys',
#  'coffee',
#  'connelsvl',
#  'rosa',
#  'ii',
#  'pronto',
#  'taco',
#  'pitt',
#  'lahvosh',
#  'sause',
#  'midtown',
#  'hoboken',
#  'bosses',
#  'knollas',
#  'veloce',
#  'hunter',
#  'nutella',
#  'chenas',
#  'hassan',
#  'pizzaworks',
#  'alaskan',
#  'baking',
#  'at',
#  'squash',
#  'piscataway',
#  'tascalis',
#  'brothers',
#  'decades',
#  'bostons',
#  'prussia',
#  'essex',
#  'booies',
#  'king',
#  'shelton',
#  'works',
#  'glutenfree',
#  'things',
#  'dietary',
#  'pagliacci',
#  'wilmington',
#  'provo',
#  'uncle',
#  "'str'>",
#  'roadhouse',
#  'jets',
#  'alley',
#  'crane',
#  'italiano',
#  'molloys',
#  'lookout',
#  'with',
#  'kyoto',
#  'clubs',
#  'casinos',
#  'pubs',
#  'pkwy',
#  'patrick',
#  'oregano',
#  'nypd',
#  'cocktails',
#  'tn',
#  'brians',
#  'ia',
#  'view',
#  'francescas',
#  'austins',
#  'mission',
#  'kilt',
#  'tilted',
#  'anchor',
#  'baldinelli',
#  'ming',
#  'beer',
#  'wi',
#  'garden',
#  'french',
#  'ross',
#  'ricotta',
#  'catering',
#  'treat',
#  'crestview',
#  'heights',
#  'moses',
#  'napolitana',
#  'brookline',
#  'herbs',
#  'gyro',
#  'louies',
#  'seeds',
#  'sioux',
#  'tre',
#  'ray',
#  'artichokes',
#  'jalapeno',
#  'sir',
#  'cheescake',
#  'rosemary',
#  'thai',
#  'avellinos',
#  'named',
#  'veggie',
#  'harrys',
#  'hunan',
#  'cupcakes',
#  'burgers',
#  'foxs',
#  'fazolis',
#  'louis',
#  'weirs',
#  'winter',
#  'tpke',
#  'moon',
#  'copelands',
#  'zpizza',
#  'plum',
#  'root',
#  'romana',
#  'steak',
#  'broccoli',
#  'laguna',
#  'niguel',
#  'grilled',
#  'asian',
#  'lover',
#  'mighty',
#  'anchovies',
#  'no',
#  'cliff',
#  'marble',
#  'tower',
#  'karaoke',
#  'mortadella',
#  'lovers',
#  'burger',
#  'gastro',
#  'university',
#  'oakridge',
#  'carrot',
#  'scallop',
#  'icon',
#  'homemade',
#  'indian',
#  'butternutsquash',
#  'http://www.co-ode.org/ontologies/pizza/pizza.owl#Country',
#  'lenoir',
#  'rhyne',
#  'adam',
#  'scott',
#  'route',
#  'combo',
#  'rock',
#  'swift',
#  'jason',
#  'ernesto',
#  'libra',
#  'indiana',
#  'rio',
#  'del',
#  'camino',
#  'esperanza',
#  'newport',
#  'plymouth',
#  'post',
#  'meaty',
#  'line',
#  'emanuel',
#  'prima',
#  'reynolda',
#  'county',
#  'maple',
#  'cascade',
#  'm',
#  'carrier',
#  'across',
#  'from',
#  'cocktail',
#  'target',
#  'kelly',
#  'own',
#  'roll',
#  'church',
#  'xing',
#  'your',
#  'build',
#  'madeira',
#  'funghi',
#  'englar',
#  'cafeteria',
#  'eureka',
#  'large',
#  'boat',
#  'nordic',
#  'eaters',
#  'whitestone',
#  'colfax',
#  'charlton',
#  'a',
#  'longmire',
#  'aubergine',
#  'ranch',
#  'pancetta',
#  'merrick',
#  'forsyth',
#  'warren',
#  'cherry',
#  'fm',
#  'comment',
#  'heart',
#  'soquel',
#  'regular',
#  'restaurants',
#  'gross',
#  'scallops',
#  'arthichoke',
#  'truffle',
#  'dye',
#  'emerson',
#  'pita',
#  'raritan',
#  'young',
#  'brigham',
#  'metropolitan',
#  'barrington',
#  'watson',
#  'el',
#  'alton',
#  'coshocton',
#  'highland',
#  'pizzatm',
#  'gay',
#  'alfredo',
#  'lago',
#  'meatball',
#  'bowl',
#  'glenway',
#  'pines',
#  'six',
#  'locker',
#  'lukes',
#  'cross',
#  'stanton',
#  'ogletown',
#  'ln',
#  'pineview',
#  'melting',
#  'pot',
#  'mamaroneck',
#  'veg',
#  'goodman',
#  'out',
#  'inc',
#  'monte',
#  'stelton',
#  'd',
#  'vino',
#  'carlo',
#  'back',
#  'michaels',
#  'delicatessen',
#  'jewish',
#  'woolworth',
#  'broadway',
#  'neck',
#  'free',
#  'charles',
#  'stratford',
#  'gluten',
#  'bread',
#  'dairy-free',
#  'south',
#  'ralphs',
#  'grocery',
#  'orlando',
#  'blockbuster',
#  'oceano',
#  'clayton',
#  'keyme',
#  'baglianis',
#  'airport',
#  'midway',
#  'sandwich',
#  'potbelly',
#  'blossom',
#  'crab',
#  'nordstrom',
#  'beppo',
#  'di',
#  'bluff',
#  'kroger',
#  'jct',
#  'buca',
#  'lakeside',
#  'entrance',
#  'coast',
#  'highway',
#  'eastern',
#  'applebees',
#  'east',
#  'spud',
#  'strang',
#  'spot',
#  'naglee',
#  'wings',
#  'gluten-free',
#  'small',
#  'spanish',
#  'mcingvale',
#  'contains',
#  'newton_highlands',
#  'mi_pals_deli_philadelphia',
#  'austins_pizza_austin',
#  'west_river_cafe_providence',
#  'gran_morsi_new_york',
#  'larosas_pizzeria_loveland',
#  'ristorante_italiano_santa_cruz',
#  'nypd_pizza_maitland',
#  'supreme_roast_beef_sea_food_danvers',
#  "'float'>",
#  'martinizing',
#  'lawrence_township',
#  'tre_restaurant_wine_bar_new_york',
#  'blue_anchor',
#  'delaware',
#  'massapequa_park',
#  'buon',
#  'uncle_johns_pizza_grand_prairie',
#  'valley_lahvosh_baking_fresno',
#  'satsuma',
#  'atheneos_greek_village_cafe_mesquite',
#  'grassfields',
#  'walnut_grille_newton_highlands',
#  'mount_ross',
#  'westgate',
#  'diolis_italian_market_winston_salem',
#  'steinway_pizza_astoria',
#  'kyoto_sushi_flushing',
#  'original_giorgios_cockeysville',
#  'cibo',
#  'franks_pizzeria_omaha',
#  'white_lake',
#  'roadhouse_cafe_hyannis',
#  'kennebunk_house_of_pizza_kennebunk',
#  'zpizza_irvine',
#  'crane_alley_urbana',
#  'corporate',
#  'bronson_strike_zone_bronson',
#  'las_vegas',
#  'the_lookout_catering_osseo',
#  'avellinos_pizza_southaven',
#  'middle_village',
#  'jets_pizza_white_lake',
#  'carluccios_philadelphia',
#  'tofu',
#  'rancho_viejo_mexican_grill_hickory',
#  'way',
#  'permanently',
#  'ogden',
#  'hl',
#  'paisans',
#  'hermosa_beach',
#  'ann',
#  'gatehouse',
#  'giovannis_pizza_and_pasta_menifee',
#  'pumpkin',
#  'sioux_city',
#  'king_of_prussia',
#  'bosses_pizza_keller_keller',
#  'euro_pizzeria_white_plains',
#  'lineage',
#  'closed',
#  'pine_plains',
#  'st_albans',
#  'tilted_kilt_mission_valley_san_diego',
#  'winston_salem',
#  'homer_glen',
#  'gina_marias_pizza_minneapolis',
#  'reserve',
#  'ming_garden_cocktails_chinese_restaurant_newark',
#  'white_plains',
#  'larosas_pizzeria_cincinnati',
#  'little_italy_pizza_memphis',
#  'los_angeles',
#  'california_pizza_kitchen_wellington',
#  'lantern',
#  'golden',
#  'bagels',
#  'love',
#  'i',
#  'little_caesars_pizza_pasadena',
#  'quincy_center',
#  'harvard',
#  'rosa_ii_pizzeria_restaurant_middle_village',
#  'tascalis_decades_pasta_grill_barboursville',
#  'prince_pizza_redford',
#  'greeks_pizzeria_indianapolis',
#  'gordon',
#  'spirits',
#  'charlies',
#  'brandos_pizza_buffalo',
#  'foolish_fasih_pizza_los_angeles',
#  'louies_pizza_newark',
#  'weirs_beach',
#  'doubledaves_pizzaworks_cedar_park',
#  'crestview_heights',
#  'rt',
#  'peter_piper_pizza_phoenix',
#  'hunan_gourmet_englishtown',
#  'cedar_park',
#  'patrick_molloys_sports_pub_hermosa_beach',
#  'grand_prairie',
#  'country_bagel_bakery_west_chester',
#  'riccardos_pizza_saddle_brook',
#  'saint_louis',
#  'taco_pronto_wichita',
#  'pirates_cove_mount_vernon',
#  'luckys_pub_houston',
#  'milanos_pizza_sacramento',
#  'doubledaves_pizza_works_college_station',
#  'laguna_niguel',
#  'antonios_pizza_chatham',
#  'ninos_trattoria_pizzeria_lawrence_township',
#  'pagliacci_pizza_kirkland',
#  'hamilton',
#  'glutenfree_things_arvada',
#  'moses_lake',
#  'mount_vernon',
#  'fazolis_bloomington',
#  'saint_albans',
#  'wildcat',
#  'baldinelli_pizza_homer_glen',
#  'casinos_pizza_addison',
#  'mediterraneo_ristorante_westminster',
#  'mount_laurel',
#  'marble_cliff',
#  'copelands_cheescake_bistro_new_orleans',
#  'mexican_gardens_southgate',
#  'the_italian_oven_connellsville',
#  'sluggers_sports_bar_erie',
#  'forest_view',
#  'the_brentwood_los_angeles',
#  'san_jose',
#  'tony_sopranos_pizza_mount_laurel',
#  'imos_pizza_arnold',
#  'new_york_city',
#  'russos_pizza_wyoming',
#  'sir_pizza_madison',
#  'china_kitchen_denver',
#  'art',
#  'college_station',
#  'la_hacienda_americus',
#  'ontario_street',
#  'richmond',
#  'salernos_pizza_restaurant_luzerne',
#  'abos_pizza_littleton',
#  'tons_drive_in_broussard',
#  'marios',
#  'foxs_pizza_den_lafayette',
#  'oh_brians_on_the_green_clark',
#  'patsys',
#  'khans',
#  'h',
#  'stissing_house_pine_plains',
#  'mount_laurel_township',
#  'pizza_bistro_massapequa_park',
#  'new_york',
#  'bostons_restaurant_sports_bar_spokane',
#  'mellow_mushroom_pizza_bakers_denver',
#  'staten_island',
#  'village_of_wellington',
#  'jersey',
#  'little_pizza_paradise_bend',
#  'san_diego',
#  'plaza',
#  'saddle_brook',
#  'santa_cruz',
#  'cristys_pizza_baltimore',
#  'tomato_basil_fairfield',
#  'ludlow',
#  'chenas_alaskan_grill_fairbanks',
#  'grandview',
#  'spagio',
#  'joeys_n_y_pizza_henderson',
#  'los_feliz',
#  'cafe_veloce_kirkland',
#  'brio',
#  'the_fire_den_alameda',
#  'city_of_spokane_valley',
#  'china_moon_suffolk',
#  'california_pizza_kitchen_austin',
#  'town_pub_bloomfield',
#  'casa_rica_westminster',
#  'zios_italian_kitchen_olathe_olathe',
#  'uno_pizzeria_grill_sturbridge_sturbridge',
#  'new_orleans',
#  'no_providence',
#  'booies_pizza_erie',
#  'francescas_on_chestnut_chicago',
#  'knollas_pizza_wichita',
#  'hungry_howies_pizza_chandler',
#  'fabulous_fasih_pizza_los_angeles',
#  'west_chester',
#  'bravo_pizza_hollywood_los_angeles',
#  's_connelsvl',
#  'tavern_at_the_inn_findlay',
#  'pie',
#  'swanton',
#  'sky',
#  'england',
#  'http://www.co-ode.org/ontologies/pizza/pizza.owl#America',
#  'subs',
#  'stewart',
#  'eatery',
#  'phillys',
#  'to',
#  'relies',
#  'ontology',
#  'this',
#  'simplicity',
#  'for',
#  '.',
#  'dip',
#  'not(c:\\users\\fasih',
#  'munir\\desktop\\knowledge',
#  'graphs',
#  'final',
#  'mos',
#  'first',
#  'pizzas',
#  'http://www.co-ode.org/ontologies/pizza/pizza.owl#Germany',
#  'france',
#  'smoked',
#  'butternut',
#  'language',
#  "''",
#  '(',
#  '``',
#  'usage',
#  'http://www.co-ode.org/ontologies/pizza/pizza.owl#France',
#  'common',
#  'germany',
#  'http://www.co-ode.org/ontologies/pizza/pizza.owl#England',
#  'edible',
#  'america',
#  'without',
#  'fresh',
#  'code',
#  'roots',
#  'leaves',
#  'stems',
#  ...]

# %%
#cosine similarity

#expect to be similar
similarity7 = wv2.similarity('chicken', 'ingredient')
similarity8 = wv2.similarity('mushroom', 'onion')
similarity9 = wv2.similarity('philadelphia', 'brentwood')

#expect to be dissimilar
similarity10 = wv2.similarity('pineapple', 'bacon')
similarity11 = wv2.similarity('country', 'pepperoni')
similarity12 = wv2.similarity('artichokes', 'oregano')

print('Expect to be Similar')
print(f"The cosine similarity between 'chicken' and 'ingredient' is {similarity7:.3f}")
print(f"The cosine similarity between 'mushroom' and 'onion' is {similarity8:.3f}")
print(f"The cosine similarity between 'philadelphia' and 'brentwood' is {similarity9:.3f}")
print('----------------------------')
print('Expect to be Not Similar')
print(f"The cosine similarity between 'pineapple' and 'bacon' is {similarity10:.3f}")
print(f"The cosine similarity between 'country' and 'pepperoni' is {similarity11:.3f}")
print(f"The cosine similarity between 'artichokes' and 'oregano' is {similarity12:.3f}")
# Out:
# Expect to be Similar
# The cosine similarity between 'chicken' and 'ingredient' is 0.707
# The cosine similarity between 'mushroom' and 'onion' is 0.730
# The cosine similarity between 'philadelphia' and 'brentwood' is 0.427
# ----------------------------
# Expect to be Not Similar
# The cosine similarity between 'pineapple' and 'bacon' is 0.827
# The cosine similarity between 'country' and 'pepperoni' is 0.555
# The cosine similarity between 'artichokes' and 'oregano' is 0.677
